# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

# %%
# Заггружаем набор данных из файла
# Первая часть тринеровочная, а на второй нейросеть тестируется
# Для второй части значения current_dist_to_target увеличивается на 482 (размерность каждой части)
training_set = pd.read_csv('data.csv')
training_set = training_set.iloc[:,1:2].values
plt.xlabel('current_dist_to_target; current_dist_to_target + 482')
plt.ylabel('angle')
plt.plot(training_set)
plt.grid()
plt.show()

# %%
# Функция алгоритма "скользящего окна"
def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x), np.array(y)

# Производим стандартизацию данных
sc = MinMaxScaler()
training_data = sc.fit_transform(training_set)

seq_length = 4
x, y = sliding_windows(training_data, seq_length)

# Задаем размеры для данных тренировки и теста (по 50%)
train_size = int(len(y) * 0.5)
test_size = len(y) - train_size

# Делаем из данных тензоры
dataX = Variable(torch.Tensor(np.array(x)))
dataY = Variable(torch.Tensor(np.array(y)))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])))

testX = Variable(torch.Tensor(np.array(x[train_size:len(x)])))
testY = Variable(torch.Tensor(np.array(y[train_size:len(y)])))

# %%
# Описание нейронной сети долгой краткосрочной памяти
class LSTM(nn.Module):
    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()

        # Количество выходных параметров
        self.num_classes = num_classes
        # Количество рекурентных слоев
        self.num_layers = num_layers
        # Количестов входных параметров
        self.input_size = input_size
        # Количетсво параметров в скрытых слоях
        self.hidden_size = hidden_size
#         self.seq_length = seq_length

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)

        # Применяем линейное преобразование к входящим данным
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))

        # Пробрасываем данные через LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))

        h_out = h_out.view(-1, self.hidden_size)

        out = self.fc(h_out)

        return out

# %%
# Количество эпох
num_epochs = 4000
# Коэффициент скорости обучения
learning_rate = 0.01

# Базовые параметры сети
input_size = 1
hidden_size = 2
num_layers = 1
num_classes = 1

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

# Среднеквадратическая ошибка для регрессии
criterion = torch.nn.MSELoss()
# Оптимизация с применением алгоритма Адама
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)

# Тренируем модель
for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    
    # Получаем функцию потерь
    loss = criterion(outputs, trainY)
    
    loss.backward()
    
    optimizer.step()

# %%
# Делаем предсказания по dataX
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

# Результат работы. Тут произведенно обратно скалирование
data_predict = sc.inverse_transform(data_predict)

# Рисуем график (красная линия разделяет train и test) 
dataY_plot = sc.inverse_transform(dataY_plot)
plt.axvline(x=train_size, c='r', linestyle='--')
plt.xlabel('current_dist_to_target; current_dist_to_target + 482')
plt.ylabel('angle')
plt.plot(dataY_plot)
plt.plot(data_predict)
plt.grid()
plt.show()

# %%
import time
import sys
import numpy as np
import vrep
from assets import *

# %%
class Algorithm:
  def __init__(self, ROBOT, TARGET):
    # Устанавливаем состояние движения
    self.state = States.MOVING

    # Минимальное и максимальное расстояние до препятствия
    self.MIN_DETECTION_DIST = 0
    self.MAX_DETECTION_DIST = 1

    # Название робота на сцене
    self.ROBOT = ROBOT
    # Название цели на сцене
    self.TARGET = TARGET
    # Скорость робота
    self.SPEED = 1.5
    # Отступ вокруг робота
    self.INDENT_DIST = 0.5

    # Задержка между выполнениями итераций цикла
    self.SLEEP_TIME = 0.2
    # Число "пи"
    self.PI = math.pi

    # Инициализация направления, позиции и значений углов Эйлера для работа
    self.bot_dir = None
    self.bot_pos = None
    self.bot_euler_angles = None

    # Инициализация позиции цели и направления до нее
    self.target_pos = None
    self.target_dir = np.zeros(3)

    # Инициализация массива значений угла поворота
    self.angle_arr = []

    # Инициализация массива значений сенсоров
    self.detect = np.zeros(16)

    # Инициализация подключения к серверу V-REP
    self._init_client_id()
    #  Инициализация хендла робота
    self._init_robot_handle()
    #  Инициализация хендлов сенсора робота
    self._init_sensor_handles()
    #  Инициализация хендлов колес робота
    self._init_wheels_handles()
    #  Инициализация хендла цели
    self._init_target_handle()

    # Инициализация частот и коэффициентов ПИД-регуляторов объезда препятствия
    self.obstacle_dist_stab_PID = PIDController(50)
    self.obstacle_follower_PID = PIDController(50)
    self.obstacle_dist_stab_PID.set_coefficients(2, 0, 0.5)
    self.obstacle_follower_PID.set_coefficients(2, 0, 0)

    # Инициализация значения ммнимальной дистанции до цели
    self.min_dist_to_target = None

    # Вывод информации
    self.print_info()


  def _init_client_id(self):
    vrep.simxFinish(-1)

    self.client_id = vrep.simxStart('127.0.0.1', 19999, True, True, 5000, 5)

    if self.client_id != -1:
      print('')
    else:
      sys.exit('')


  def _init_robot_handle(self):
    error_code, self.bot_handle = vrep.simxGetObjectHandle(self.client_id, self.ROBOT, vrep.simx_opmode_oneshot_wait)


  def _init_sensor_handles(self):
    self.sensor_handles = []

    for x in range(0, 16):
      error_code, sensor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_ultrasonicSensor' + str(x + 1), vrep.simx_opmode_oneshot_wait)
      self.sensor_handles.append(sensor_handle)
      vrep.simxReadProximitySensor(self.client_id, sensor_handle, vrep.simx_opmode_streaming)


  def _init_wheels_handles(self):
    error_code, self.left_motor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_leftMotor', vrep.simx_opmode_oneshot_wait)
    error_code, self.right_motor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_rightMotor', vrep.simx_opmode_oneshot_wait)


  def _init_target_handle(self):
    error_code, self.target_handle = vrep.simxGetObjectHandle(self.client_id, self.TARGET, vrep.simx_opmode_oneshot_wait)


  def _init_values(self):
    # Инициализация значений цели и робота
    error_code, _ = vrep.simxGetObjectPosition(self.client_id, self.target_handle, -1, vrep.simx_opmode_oneshot)
    error_code, _ = vrep.simxGetObjectPosition(self.client_id, self.bot_handle, -1, vrep.simx_opmode_oneshot)
    error_code, _ = vrep.simxGetObjectOrientation(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)


  def read_values(self):
    # Чтение значений позиции цели
    error_code, target_pos = vrep.simxGetObjectPosition(self.client_id, self.target_handle, -1, vrep.simx_opmode_streaming)
    self.target_pos = Vector3(x=target_pos[0], y=target_pos[1], z=0)

    # Чтение значений позиции робота
    error_code, bot_pos = vrep.simxGetObjectPosition(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)
    self.bot_pos = Vector3(x=bot_pos[0], y=bot_pos[1], z=0)

    # Чтение значений углов Эйлера робота
    error_code, bot_euler_angles = vrep.simxGetObjectOrientation(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)
    self.bot_euler_angles = Vector3(x=0, y=0, z=bot_euler_angles[2])


  def stop_move(self):
    # Остановка движения робота
    error_code = vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  0, vrep.simx_opmode_streaming)
    error_code = vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, 0, vrep.simx_opmode_streaming)


  def read_from_sensors(self):
    # Чтение значений с сенсоров
    for i in range(0, 16):
      error_code, detection_state, detected_point, detected_object_handle, detected_surface_normal_vector = vrep.simxReadProximitySensor(self.client_id, self.sensor_handles[i], vrep.simx_opmode_streaming)

      # Значение дистанции до препятствия
      dist = math.sqrt(detected_point[0] ** 2 + detected_point[1] ** 2 + detected_point[2] ** 2)

      # Присвоение значений датчиков: чем больше значение, тем ближе к конкретному датчику препятствие
      if dist < self.MIN_DETECTION_DIST:
        self.detect[i] = self.MIN_DETECTION_DIST
      elif dist > self.MAX_DETECTION_DIST or detection_state == False:
        self.detect[i] = self.MAX_DETECTION_DIST
      else:
        self.detect[i] = self.MAX_DETECTION_DIST - ((dist - self.MAX_DETECTION_DIST) / (self.MIN_DETECTION_DIST - self.MAX_DETECTION_DIST))


  def print_info(self):
    print('Цель: ' + self.TARGET)
    print('Робот: ' + self.ROBOT)
    print('Скорость: ' + str(self.SPEED))


  def tick(self):
    # Задержка программы
    time.sleep(self.SLEEP_TIME)


  def loop(self):
    self._init_values()
    self.read_values()

    distance_to_target = Utils.distance_between_points(self.bot_pos, self.target_pos)
    # Основной цикл программы
    while distance_to_target > 0.4 or distance_to_target == 0:
      self.tick()

      # Останавливаем движение и читаем данные робота и цели
      self.stop_move()
      self.read_values()

      # Получаем данные с сенсоров
      self.read_from_sensors()

      # Инициализируем новый кватернион
      q_rot = Quaternion()
      # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
      q_rot.set_from_vector(self.bot_euler_angles.z, Vector3(0, 0, 1))
      # Присваиваем вектору робота значения поворота вектора кватернионом
      self.bot_dir = q_rot.rotate(Vector3(1, 0, 0))

      # Проверка текущего состояния и выполнение соответствующей функции
      if self.state == States.MOVING:
        self.action_moving()
      elif self.state == States.ROTATING:
        self.action_rotating()
      elif self.state == States.ROUNDING:
        self.action_rounding()

    print('Цель достигнута')
    self.stop_move()


  def action_moving(self):
    # Если робот оказалася близко к препятствию, объезжаем это препятствие, иначе продолжаем движение до цели
    if (self.detect[4] + self.detect[5])/2 < self.INDENT_DIST:
      # Инициализируем новый кватернион
      q = Quaternion()
      # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
      q.set_from_vector(self.PI/2, Vector3(0, 0, 1))
      # Присваиваем вектору цели значения поворота вектора направления робота кватернионом
      self.target_dir = q.rotate(self.bot_dir)
      # Переключаем состояние
      self.state = States.ROTATING
    else:
      # Значение угла в радианах между векторами направления движения робота и между роботом и целью
      angle = Utils.angle_between_vectors(self.bot_dir, self.target_pos.minus(self.bot_pos))

      # Корректируем движение робота до прямолинейного до цели, если необходимо
      if math.fabs(angle) > self.PI/180:
        vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  self.SPEED + angle, vrep.simx_opmode_streaming)
        vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED - angle, vrep.simx_opmode_streaming)
      else:
        vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  self.SPEED, vrep.simx_opmode_streaming)
        vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED, vrep.simx_opmode_streaming)


  def action_rotating(self):
    # Значение угла в радианах между векторами направления движения робота и цели
    angle = Utils.angle_between_vectors(self.bot_dir, self.target_dir)

    # Поворачиваем робота вокруг своей оси, если необходимо, иначе переключаем состояние
    if math.fabs(angle) > 5 * self.PI/180:
      vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle, angle, vrep.simx_opmode_streaming)
      vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, -angle, vrep.simx_opmode_streaming)
    else:
      self.state = States.ROUNDING


  def action_rounding(self):
    # Инициализация нового кватерниона
    q = Quaternion()
    # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
    q.set_from_vector(self.PI/2, Vector3(0, 0, 1))
    # Присваиваем перпендикуляру вектора робота значения поворота вектора направления робота кватернионом
    perp_bot_dir = q.rotate(self.bot_dir)

    # Значение угла в радианах между векторами перпендикуляра к роботу и между роботом и целью
    angle = Utils.angle_between_vectors(perp_bot_dir, self.target_pos.minus(self.bot_pos))

    # Запишем данные angle в файл
    f1 = open('f1.txt', 'a')
    z = str(angle)
    f1.write(z+'\n')
    self.angle_arr.append(angle)

    # Текущая дистанция до цели
    current_dist_to_target_real = Utils.distance_between_points(self.bot_pos, self.target_pos)
    current_dist_to_target_predict = data_predict[len(self.angle_arr)]
    print('predict',current_dist_to_target_predict)
    print('real', current_dist_to_target_real)

    # Запишем данные current_dist_to_target_real в файл
    f2 = open('f2.txt', 'a')
    m = str(current_dist_to_target_real)
    f2.write(m+'\n')

    # Если минимальное значение дистанции до цели меньше, чем текущее, то присваиваем минимальному значению текущее
    if self.min_dist_to_target == None or self.min_dist_to_target <= current_dist_to_target_predict:
      self.min_dist_to_target = current_dist_to_target_predict
    # Прекращаем объезд препятствия
    elif math.fabs(angle) < 5.0 / 180 * self.PI:
      self.state = States.MOVING
      return

    # Разница между значениями двух крайних справа датчиков
    delta = self.detect[7] - self.detect[8]

    # Устанавливаем расстояние до препятствия
    obstacle_dist = min([self.detect[7], self.detect[8]]) - self.INDENT_DIST

    obstacle_dist_stab = self.obstacle_dist_stab_PID.output(obstacle_dist)
    obstacle_follower = self.obstacle_follower_PID.output(delta)
  
    vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle, self.SPEED + obstacle_follower + obstacle_dist_stab - (1 - (self.detect[4] + self.detect[5])/2), vrep.simx_opmode_streaming)
    vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED - obstacle_follower - obstacle_dist_stab + (1 - (self.detect[4] + self.detect[5])/2), vrep.simx_opmode_streaming)


bug = Algorithm(ROBOT='P3DX', TARGET='Destination')

bug.loop()
# Out:
# Цель: Destination
# Робот: P3DX
# Скорость: 1.5
# ('predict', array([7.8274713], dtype=float32))
# ('real', 7.900984949491765)
# ('predict', array([7.8438087], dtype=float32))
# ('real', 7.905642626278827)
# ('predict', array([7.863402], dtype=float32))
# ('real', 7.922591389130467)
# ('predict', array([7.8822246], dtype=float32))
# ('real', 7.942930347641438)
# ('predict', array([7.895542], dtype=float32))
# ('real', 7.952765349498724)
# ('predict', array([7.9075217], dtype=float32))
# ('real', 7.952876310135403)
# ('predict', array([7.916376], dtype=float32))
# ('real', 7.941322914775701)
# ('predict', array([7.9209833], dtype=float32))
# ('real', 7.916263529114473)
# ('predict', array([7.920593], dtype=float32))
# ('real', 7.8965563357062685)
# ('predict', array([7.9139633], dtype=float32))
# ('real', 7.884246327787726)
# ('predict', array([7.9012666], dtype=float32))
# ('real', 7.876497255726817)
# ('predict', array([7.8915906], dtype=float32))
# ('real', 7.86875132961009)
# ('predict', array([7.8829355], dtype=float32))
# ('real', 7.862224517744785)
# ('predict', array([7.8764067], dtype=float32))
# ('real', 7.855074911509743)
# ('predict', array([7.8707275], dtype=float32))
# ('real', 7.849382313193733)
# ('predict', array([7.8647733], dtype=float32))
# ('real', 7.844025327791773)
# ('predict', array([7.86005], dtype=float32))
# ('real', 7.839231904766567)
# ('predict', array([7.855973], dtype=float32))
# ('real', 7.8346127294469206)
# ('predict', array([7.851695], dtype=float32))
# ('real', 7.830145180587561)
# ('predict', array([7.848285], dtype=float32))
# ('real', 7.826617301969492)
# ('predict', array([7.845314], dtype=float32))
# ('real', 7.823290640776389)
# ('predict', array([7.842193], dtype=float32))
# ('real', 7.819612769233819)
# ('predict', array([7.839322], dtype=float32))
# ('real', 7.817725212449233)
# ('predict', array([7.8371806], dtype=float32))
# ('real', 7.815697977925455)
# ('predict', array([7.8356333], dtype=float32))
# ('real', 7.813282853366587)
# ('predict', array([7.833557], dtype=float32))
# ('real', 7.8127444610177195)
# ('predict', array([7.8316865], dtype=float32))
# ('real', 7.812220494034494)
# ('predict', array([7.830026], dtype=float32))
# ('real', 7.811648393024333)
# ('predict', array([7.829054], dtype=float32))
# ('real', 7.8109247294226405)
# ('predict', array([7.8278966], dtype=float32))
# ('real', 7.811920040146316)
# ('predict', array([7.8268194], dtype=float32))
# ('real', 7.813219547527746)
# ('predict', array([7.826525], dtype=float32))
# ('real', 7.814428756988985)
# ('predict', array([7.8261127], dtype=float32))
# ('real', 7.815925923791443)
# ('predict', array([7.826121], dtype=float32))
# ('real', 7.817811678827107)
# ('predict', array([7.8259525], dtype=float32))
# ('real', 7.82043254902934)
# ('predict', array([7.826348], dtype=float32))
# ('real', 7.823449822967106)
# ('predict', array([7.8267574], dtype=float32))
# ('real', 7.828084783556957)
# ('predict', array([7.827569], dtype=float32))
# ('real', 7.833122277586211)
# ('predict', array([7.828442], dtype=float32))
# ('real', 7.837910583673574)
# ('predict', array([7.829744], dtype=float32))
# ('real', 7.841971943302736)
# ('predict', array([7.831027], dtype=float32))
# ('real', 7.846950327136044)
# ('predict', array([7.832643], dtype=float32))
# ('real', 7.852296589687886)
# ('predict', array([7.8342814], dtype=float32))
# ('real', 7.858098483540454)
# ('predict', array([7.836523], dtype=float32))
# ('real', 7.864382020790815)
# ('predict', array([7.8390484], dtype=float32))
# ('real', 7.87027725746641)
# ('predict', array([7.842108], dtype=float32))
# ('real', 7.87746961193323)
# ('predict', array([7.8446727], dtype=float32))
# ('real', 7.881218231766954)
# ('predict', array([7.8476257], dtype=float32))
# ('real', 7.884129108543022)
# ('predict', array([7.850681], dtype=float32))
# ('real', 7.894267736897845)
# ('predict', array([7.8534026], dtype=float32))
# ('real', 7.900608256081477)
# ('predict', array([7.856184], dtype=float32))
# ('real', 7.909534382089039)
# ('predict', array([7.8596287], dtype=float32))
# ('real', 7.917994132883686)
# ('predict', array([7.862747], dtype=float32))
# ('real', 7.926234104725502)
# ('predict', array([7.8665476], dtype=float32))
# ('real', 7.931273202340489)
# ('predict', array([7.870669], dtype=float32))
# ('real', 7.928686692477492)
# ('predict', array([7.8750935], dtype=float32))
# ('real', 7.922960127447843)
# ('predict', array([7.879077], dtype=float32))
# ('real', 7.9150398374014275)
# ('predict', array([7.883923], dtype=float32))
# ('real', 7.902586573962424)
# ('predict', array([7.8891387], dtype=float32))
# ('real', 7.896392377782391)
# ('predict', array([7.8938217], dtype=float32))
# ('real', 7.885274901950034)
# ('predict', array([7.8994565], dtype=float32))
# ('real', 7.878355926541794)
# ('predict', array([7.9057293], dtype=float32))
# ('real', 7.865535772381327)
# ('predict', array([7.9111404], dtype=float32))
# ('real', 7.843367973465103)
# ('predict', array([7.916793], dtype=float32))
# ('real', 7.830344249126234)
# ('predict', array([7.922695], dtype=float32))
# ('real', 7.798745104633467)
# ('predict', array([7.9297247], dtype=float32))
# ('real', 7.785550392897528)
# ('predict', array([7.931906], dtype=float32))
# ('real', 7.756957448598063)
# ('predict', array([7.927835], dtype=float32))
# ('real', 7.721506923202072)
# ('predict', array([7.920329], dtype=float32))
# ('real', 7.695082690303551)
# ('predict', array([7.9120326], dtype=float32))
# ('real', 7.650987740470842)
# ('predict', array([7.903345], dtype=float32))
# ('real', 7.6110900086549105)
# ('predict', array([7.8954005], dtype=float32))
# ('real', 7.575710800957222)
# ('predict', array([7.885129], dtype=float32))
# ('real', 7.538773555693638)
# ('predict', array([7.872212], dtype=float32))
# ('real', 7.513536681773947)
# ('predict', array([7.856403], dtype=float32))
# ('real', 7.480667789239246)
# ('predict', array([7.8378577], dtype=float32))
# ('real', 7.426766675891954)
# ('predict', array([7.8166866], dtype=float32))
# ('real', 7.371242205744975)
# ('predict', array([7.796731], dtype=float32))
# ('real', 7.343385414762469)
# ('predict', array([7.775464], dtype=float32))
# ('real', 7.315443559955769)
# ('predict', array([7.74877], dtype=float32))
# ('real', 7.266125027714135)
# ('predict', array([7.7241254], dtype=float32))
# ('real', 7.209343217771461)
# ('predict', array([7.6968985], dtype=float32))
# ('real', 7.180817724640738)
# ('predict', array([7.665275], dtype=float32))
# ('real', 7.130720642713962)
# ('predict', array([7.636837], dtype=float32))
# ('real', 7.0806174244529005)
# ('predict', array([7.6025286], dtype=float32))
# ('real', 7.037674615892444)
# ('predict', array([7.5656757], dtype=float32))
# ('real', 6.9941784051417555)
# ('predict', array([7.526846], dtype=float32))
# ('real', 6.965357916586738)
# ('predict', array([7.4928946], dtype=float32))
# ('real', 6.915623616467646)
# ('predict', array([7.4523425], dtype=float32))
# ('real', 6.86650800381993)
# ('predict', array([7.410164], dtype=float32))
# ('real', 6.838963692765597)
# ('predict', array([7.3740244], dtype=float32))
# ('real', 6.811737077085238)
# ('predict', array([7.3321753], dtype=float32))
# ('real', 6.759000479640188)
# ('predict', array([7.2889347], dtype=float32))
# ('real', 6.727209879627462)
# ('predict', array([7.2452908], dtype=float32))
# ('real', 6.678352578448364)
# ('predict', array([7.208359], dtype=float32))
# ('real', 6.6376664529672915)
# ('predict', array([7.1654186], dtype=float32))
# ('real', 6.604592977783885)
# ('predict', array([7.1280737], dtype=float32))
# ('real', 6.5732304880316965)
# ('predict', array([7.0846567], dtype=float32))
# ('real', 6.558109831932213)
# ('predict', array([7.0473247], dtype=float32))
# ('real', 6.525065465627136)
# ('predict', array([7.024509], dtype=float32))
# ('real', 6.494679763838269)
# ('predict', array([6.996552], dtype=float32))
# ('real', 6.467187529418815)
# ('predict', array([6.960182], dtype=float32))
# ('real', 6.4365919958206055)
# ('predict', array([6.916167], dtype=float32))
# ('real', 6.416712818869288)
# ('predict', array([6.879074], dtype=float32))
# ('real', 6.398286181553891)
# ('predict', array([6.8370166], dtype=float32))
# ('real', 6.389140159310676)
# ('predict', array([6.7949295], dtype=float32))
# ('real', 6.380472036265038)
# ('predict', array([6.760335], dtype=float32))
# ('real', 6.37493004398284)
# ('predict', array([6.721755], dtype=float32))
# ('real', 6.368356262984687)
# ('predict', array([6.689584], dtype=float32))
# ('real', 5.827441698105205)
# ('predict', array([6.653289], dtype=float32))
# ('real', 5.820797774739144)
# ('predict', array([6.623321], dtype=float32))
# ('real', 5.810110373571811)
# ('predict', array([6.5897193], dtype=float32))
# ('real', 5.82554842291117)
# ('predict', array([6.557252], dtype=float32))
# ('real', 5.847661528516936)
# ('predict', array([6.531581], dtype=float32))
# ('real', 5.873472951698722)
# ('predict', array([6.508111], dtype=float32))
# ('real', 5.901185749976084)
# ('predict', array([6.481631], dtype=float32))
# ('real', 5.921737918353477)
# ('predict', array([6.4604535], dtype=float32))
# ('real', 5.9366020696943345)
# ('predict', array([6.4380746], dtype=float32))
# ('real', 5.942692981051326)
# ('predict', array([6.4176474], dtype=float32))
# ('real', 5.9454314376338075)
# ('predict', array([6.399721], dtype=float32))
# ('real', 5.952350308130788)
# ('predict', array([6.386832], dtype=float32))
# ('real', 5.957935039716244)
# ('predict', array([6.373996], dtype=float32))
# ('real', 5.9674243104804345)
# ('predict', array([6.365054], dtype=float32))
# ('real', 5.976046732135367)
# ('predict', array([6.3566837], dtype=float32))
# ('real', 5.989060598426538)
# ('predict', array([6.3512044], dtype=float32))
# ('real', 5.994901215858328)
# ('predict', array([6.3464065], dtype=float32))
# ('real', 6.004962962469757)
# ('predict', array([5.8358593], dtype=float32))
# ('real', 6.017292235090429)
# ('predict', array([5.77448], dtype=float32))
# ('real', 6.029893024912644)
# ('predict', array([5.794018], dtype=float32))
# ('real', 6.044651148239373)
# ('predict', array([5.8161826], dtype=float32))
# ('real', 6.059312285242345)
# ('predict', array([5.8251705], dtype=float32))
# ('real', 6.069592490329686)
# ('predict', array([5.8361034], dtype=float32))
# ('real', 6.081612909387254)
# ('predict', array([5.848692], dtype=float32))
# ('real', 6.095439712198846)
# ('predict', array([5.8625617], dtype=float32))
# ('real', 6.111630678671501)
# ('predict', array([5.8767533], dtype=float32))
# ('real', 6.122165329707741)
# ('predict', array([5.8884788], dtype=float32))
# ('real', 6.137362932791565)
# ('predict', array([5.900413], dtype=float32))
# ('real', 6.155457855658601)
# ('predict', array([5.912843], dtype=float32))
# ('real', 6.174390457838092)
# ('predict', array([5.9227533], dtype=float32))
# ('real', 6.191608709027636)
# ('predict', array([5.933548], dtype=float32))
# ('real', 6.211881734270974)
# ('predict', array([5.944062], dtype=float32))
# ('real', 6.232604755672917)
# ('predict', array([5.9542193], dtype=float32))
# ('real', 6.248267675497385)
# ('predict', array([5.9625587], dtype=float32))
# ('real', 6.258695679394032)
# ('predict', array([5.972523], dtype=float32))
# ('real', 6.271679440318541)
# ('predict', array([5.983134], dtype=float32))
# ('real', 6.287339035500427)
# ('predict', array([5.9942675], dtype=float32))
# ('real', 6.30325207057666)
# ('predict', array([6.003976], dtype=float32))
# ('real', 6.316754168155276)
# ('predict', array([6.015982], dtype=float32))
# ('real', 6.324959907324653)
# ('predict', array([6.0288124], dtype=float32))
# ('real', 6.3360181891218685)
# ('predict', array([6.039839], dtype=float32))
# ('real', 6.3472117078090875)
# ('predict', array([6.0529633], dtype=float32))
# ('real', 6.3472117078090875)
# ('predict', array([6.064386], dtype=float32))
# ('real', 6.367134880415773)
# ('predict', array([6.0778427], dtype=float32))
# ('real', 6.390409246861364)
# ('predict', array([6.0915546], dtype=float32))
# ('real', 6.411204197491999)
# ('predict', array([6.104107], dtype=float32))
# ('real', 6.420196249580376)
# ('predict', array([6.11529], dtype=float32))
# ('real', 6.420196249580376)
# ('predict', array([6.1287284], dtype=float32))
# ('real', 6.43225119326165)
# ('predict', array([6.142633], dtype=float32))
# ('real', 6.441402685727193)
# ('predict', array([6.1543655], dtype=float32))
# ('real', 6.453768973394958)
# ('predict', array([6.1683803], dtype=float32))
# ('real', 6.47276904649295)
# ('predict', array([6.18309], dtype=float32))
# ('real', 6.495817903178331)
# ('predict', array([6.195691], dtype=float32))
# ('real', 6.516683662707468)
# ('predict', array([6.210668], dtype=float32))
# ('real', 6.530979722877006)
# ('predict', array([6.2237816], dtype=float32))
# ('real', 6.5524683622456665)
# ('predict', array([6.2394667], dtype=float32))
# ('real', 6.580821250676421)
# ('predict', array([6.255721], dtype=float32))
# ('real', 6.604979749297493)
# ('predict', array([6.269482], dtype=float32))
# ('real', 6.627785851041669)
# ('predict', array([6.285734], dtype=float32))
# ('real', 6.650249827505269)
# ('predict', array([6.3026075], dtype=float32))
# ('real', 6.676658093387144)
# ('predict', array([6.316839], dtype=float32))
# ('real', 6.70045391495552)
# ('predict', array([6.333647], dtype=float32))
# ('real', 6.728214764727692)
# ('predict', array([6.351065], dtype=float32))
# ('real', 6.752936749398692)
# ('predict', array([6.3658023], dtype=float32))
# ('real', 6.781654042690967)
# ('predict', array([6.3774056], dtype=float32))
# ('real', 6.792547042804829)
# ('predict', array([6.3948135], dtype=float32))
# ('real', 6.807168839948459)
# ('predict', array([6.413273], dtype=float32))
# ('real', 6.8255881405416385)
# ('predict', array([6.4288692], dtype=float32))
# ('real', 6.8553637527369276)
# ('predict', array([6.4443016], dtype=float32))
# ('real', 6.874159902862723)
# ('predict', array([6.463576], dtype=float32))
# ('real', 6.8854515310770905)
# ('predict', array([6.484274], dtype=float32))
# ('real', 6.904668534208546)
# ('predict', array([6.5020556], dtype=float32))
# ('real', 6.9270350035156)
# ('predict', array([6.5229464], dtype=float32))
# ('real', 6.941205822158362)
# ('predict', array([6.544242], dtype=float32))
# ('real', 6.963279989316905)
# ('predict', array([6.561812], dtype=float32))
# ('real', 6.982338034098415)
# ('predict', array([6.581793], dtype=float32))
# ('real', 6.9978447822394285)
# ('predict', array([6.6016626], dtype=float32))
# ('real', 7.005831796850966)
# ('predict', array([6.6184745], dtype=float32))
# ('real', 7.014024680430605)
# ('predict', array([6.6351433], dtype=float32))
# ('real', 7.017415048617755)
# ('predict', array([6.655516], dtype=float32))
# ('real', 7.020334375351061)
# ('predict', array([6.673246], dtype=float32))
# ('real', 7.022481512759577)
# ('predict', array([6.6940827], dtype=float32))
# ('real', 7.0231484749934605)
# ('predict', array([6.712118], dtype=float32))
# ('real', 7.022036967638565)
# ('predict', array([6.729952], dtype=float32))
# ('real', 7.017543714702248)
# ('predict', array([6.751481], dtype=float32))
# ('real', 7.007975767021113)
# ('predict', array([6.7702217], dtype=float32))
# ('real', 6.992202295151143)
# ('predict', array([6.79217], dtype=float32))
# ('real', 6.968798765324703)
# ('predict', array([6.8148065], dtype=float32))
# ('real', 6.9430052861972245)
# ('predict', array([6.8340917], dtype=float32))
# ('real', 6.927643942144562)
# ('predict', array([6.8529077], dtype=float32))
# ('real', 6.903669441111967)
# ('predict', array([6.8755517], dtype=float32))
# ('real', 6.8557327861642925)
# ('predict', array([6.8955097], dtype=float32))
# ('real', 6.837108486323679)
# ('predict', array([6.916025], dtype=float32))
# ('real', 6.797269746201995)
# ('predict', array([6.9361196], dtype=float32))
# ('real', 6.760143681921919)
# ('predict', array([6.950234], dtype=float32))
# ('real', 6.7215376429434714)
# ('predict', array([6.96154], dtype=float32))
# ('real', 6.676261590261551)
# ('predict', array([6.970497], dtype=float32))
# ('real', 6.629411678127974)
# ('predict', array([6.9811287], dtype=float32))
# ('real', 6.580707659256588)
# ('predict', array([6.9914103], dtype=float32))
# ('real', 6.53659908154928)
# ('predict', array([6.999174], dtype=float32))
# ('real', 6.4977378347087855)
# ('predict', array([7.006174], dtype=float32))
# ('real', 6.484587426357161)
# ('predict', array([7.010369], dtype=float32))
# ('real', 6.464647687549348)
# ('predict', array([7.0110235], dtype=float32))
# ('real', 6.437793646149513)
# ('predict', array([7.0080905], dtype=float32))
# ('real', 6.410663197901954)
# ('predict', array([7.0016646], dtype=float32))
# ('real', 6.383187130056509)
# ('predict', array([6.994131], dtype=float32))
# ('real', 6.341365599130654)
# ('predict', array([6.9832754], dtype=float32))
# ('real', 6.313322992905736)
# ('predict', array([6.970474], dtype=float32))
# ('real', 6.306296462169535)
# ('predict', array([6.956099], dtype=float32))
# ('real', 6.292190242053327)
# ('predict', array([6.9425426], dtype=float32))
# ('real', 6.2564954181574315)
# ('predict', array([6.9248505], dtype=float32))
# ('real', 6.235137828381145)
# ('predict', array([6.904545], dtype=float32))
# ('real', 6.199307476658251)
# ('predict', array([6.8818874], dtype=float32))
# ('real', 6.16340542289872)
# ('predict', array([6.860732], dtype=float32))
# ('real', 6.106106540010803)
# ('predict', array([6.833546], dtype=float32))
# ('real', 6.063285668112475)
# ('predict', array([6.8031354], dtype=float32))
# ('real', 6.020661393446989)
# ('predict', array([6.770712], dtype=float32))
# ('real', 5.9716401693894765)
# ('predict', array([6.742489], dtype=float32))
# ('real', 5.916646640260061)
# ('predict', array([6.708887], dtype=float32))
# ('real', 5.869553848361454)
# ('predict', array([6.673716], dtype=float32))
# ('real', 5.836800118672759)
# ('predict', array([6.6377487], dtype=float32))
# ('real', 5.792450133725987)
# ('predict', array([6.6069717], dtype=float32))
# ('real', 5.756001696636244)
# ('predict', array([6.5701094], dtype=float32))
# ('real', 5.714865502529634)
# ('predict', array([6.5315776], dtype=float32))
# ('real', 5.67608881839503)
# ('predict', array([6.492093], dtype=float32))
# ('real', 5.634877439914172)
# ('predict', array([6.4585133], dtype=float32))
# ('real', 5.6019412887712745)
# ('predict', array([6.418432], dtype=float32))
# ('real', 5.5710896468744915)
# ('predict', array([6.376621], dtype=float32))
# ('real', 5.538084651437233)
# ('predict', array([6.3411894], dtype=float32))
# ('real', 5.510903558117579)
# ('predict', array([6.2993255], dtype=float32))
# ('real', 5.480539740810147)
# ('predict', array([6.256054], dtype=float32))
# ('real', 5.4656757831687885)
# ('predict', array([6.2197304], dtype=float32))
# ('real', 5.447006713237283)
# ('predict', array([6.177202], dtype=float32))
# ('real', 5.43237489927432)
# ('predict', array([6.140782], dtype=float32))
# ('real', 5.410789689773134)
# ('predict', array([6.0981045], dtype=float32))
# ('real', 5.347729760566586)
# ('predict', array([6.0547633], dtype=float32))
# ('real', 5.337435401707235)
# ('predict', array([6.0117507], dtype=float32))
# ('real', 5.319715402044029)
# ('predict', array([5.976412], dtype=float32))
# ('real', 5.294267230065109)
# ('predict', array([5.9355145], dtype=float32))
# ('real', 5.2836604362021395)
# ('predict', array([5.894153], dtype=float32))
# ('real', 5.262428891316802)
# ('predict', array([5.8539667], dtype=float32))
# ('real', 5.238240117028787)
# ('predict', array([5.8213873], dtype=float32))
# ('real', 5.221217400055023)
# ('predict', array([5.7840242], dtype=float32))
# ('real', 5.207452054454168)
# ('predict', array([5.7469606], dtype=float32))
# ('real', 5.183437434269198)
# ('predict', array([5.717419], dtype=float32))
# ('real', 5.159883241882316)
# ('predict', array([5.6839514], dtype=float32))
# ('real', 5.132939269175209)
# ('predict', array([5.651235], dtype=float32))
# ('real', 5.106095639401276)
# ('predict', array([5.6256595], dtype=float32))
# ('real', 5.082677957902609)
# ('predict', array([5.597572], dtype=float32))
# ('real', 5.056102606520941)
# ('predict', array([5.5704503], dtype=float32))
# ('real', 5.029933810495275)
# ('predict', array([5.549261], dtype=float32))
# ('real', 5.00409721530808)
# ('predict', array([5.5276747], dtype=float32))
# ('real', 4.978696489759839)
# ('predict', array([5.50839], dtype=float32))
# ('real', 4.953704060253306)
# ('predict', array([5.4860144], dtype=float32))
# ('real', 4.932233391380424)
# ('predict', array([5.463982], dtype=float32))
# ('real', 4.914053264334014)
# ('predict', array([5.4460835], dtype=float32))
# ('real', 4.893205348022816)
# ('predict', array([5.4251885], dtype=float32))
# ('real', 4.8757261852458225)
# ('predict', array([5.407494], dtype=float32))
# ('real', 4.864255382051005)
# ('predict', array([5.386782], dtype=float32))
# ('real', 4.844433857825712)
# ('predict', array([5.3657026], dtype=float32))
# ('real', 4.825196332501136)
# ('predict', array([5.348281], dtype=float32))
# ('real', 4.806073750214779)
# ('predict', array([5.3277817], dtype=float32))
# ('real', 4.78572741713225)
# ('predict', array([5.306816], dtype=float32))
# ('real', 4.768059145060399)
# ('predict', array([5.2894573], dtype=float32))
# ('real', 4.74788544623432)
# ('predict', array([5.269099], dtype=float32))
# ('real', 4.729394281062739)
# ('predict', array([5.248241], dtype=float32))
# ('real', 4.710616288148693)
# ('predict', array([5.231045], dtype=float32))
# ('real', 4.6933365424256435)
# ('predict', array([5.210882], dtype=float32))
# ('real', 4.677889935401771)
# ('predict', array([5.190228], dtype=float32))
# ('real', 4.661576684138108)
# ('predict', array([5.173244], dtype=float32))
# ('real', 4.645116066154056)
# ('predict', array([5.1533837], dtype=float32))
# ('real', 4.63198286912274)
# ('predict', array([5.1364245], dtype=float32))
# ('real', 4.618565144570468)
# ('predict', array([5.1166487], dtype=float32))
# ('real', 4.608144991736822)
# ('predict', array([5.096561], dtype=float32))
# ('real', 4.599221849688997)
# ('predict', array([5.080088], dtype=float32))
# ('real', 4.587441677443146)
# ('predict', array([5.062587], dtype=float32))
# ('real', 4.5800070385622265)
# ('predict', array([5.0464196], dtype=float32))
# ('real', 4.569165759578003)
# ('predict', array([5.0288467], dtype=float32))
# ('real', 4.559438502082572)
# ('predict', array([5.0095944], dtype=float32))
# ('real', 4.548637078071717)
# ('predict', array([4.9904094], dtype=float32))
# ('real', 4.537978437321507)
# ('predict', array([4.9748473], dtype=float32))
# ('real', 4.528987407509883)
# ('predict', array([4.9567356], dtype=float32))
# ('real', 4.518350500820569)
# ('predict', array([4.938204], dtype=float32))
# ('real', 4.510942326492662)
# ('predict', array([4.923117], dtype=float32))
# ('real', 4.504527271070923)
# ('predict', array([4.905638], dtype=float32))
# ('real', 4.49920434633524)
# ('predict', array([4.8907776], dtype=float32))
# ('real', 4.4940304153601405)
# ('predict', array([4.8736005], dtype=float32))
# ('real', 4.4888288095374245)
# ('predict', array([4.8591385], dtype=float32))
# ('real', 4.48504951288669)
# ('predict', array([4.8438325], dtype=float32))
# ('real', 2.763597691268778)
# ('predict', array([4.827458], dtype=float32))
# ('real', 2.7570414218839354)
# ('predict', array([4.813925], dtype=float32))
# ('real', 2.7579882542228202)
# ('predict', array([4.798064], dtype=float32))
# ('real', 2.770260588789704)
# ('predict', array([4.782459], dtype=float32))
# ('real', 2.780271114347518)
# ('predict', array([4.7698717], dtype=float32))
# ('real', 2.79333391822591)
# ('predict', array([4.756468], dtype=float32))
# ('real', 2.8108708050102527)
# ('predict', array([4.741422], dtype=float32))
# ('real', 2.8222672614112954)
# ('predict', array([4.729702], dtype=float32))
# ('real', 2.827996414093715)
# ('predict', array([4.7163134], dtype=float32))
# ('real', 2.8324820889735367)
# ('predict', array([4.7045617], dtype=float32))
# ('real', 2.8349492748696523)
# ('predict', array([4.691626], dtype=float32))
# ('real', 2.8391994486167222)
# ('predict', array([4.678292], dtype=float32))
# ('real', 2.841170743411825)
# ('predict', array([4.667862], dtype=float32))
# ('real', 2.841170743411825)
# ('predict', array([4.6557417], dtype=float32))
# ('real', 2.8468829520865095)
# ('predict', array([4.645588], dtype=float32))
# ('real', 2.8506015333888826)
# ('predict', array([4.6338506], dtype=float32))
# ('real', 2.8582545494362934)
# ('predict', array([4.62218], dtype=float32))
# ('real', 2.8662610238757975)
# ('predict', array([4.613396], dtype=float32))
# ('real', 2.8774748412567246)
# ('predict', array([4.603067], dtype=float32))
# ('real', 2.884929115588521)
# ('predict', array([4.5946274], dtype=float32))
# ('real', 2.8959073185055284)
# ('predict', array([4.5846205], dtype=float32))
# ('real', 2.9089433863794514)
# ('predict', array([4.576426], dtype=float32))
# ('real', 2.922316175568103)
# ('predict', array([4.5679026], dtype=float32))
# ('real', 2.934528148464748)
# ('predict', array([4.5604568], dtype=float32))
# ('real', 2.938699333282544)
# ('predict', array([4.551969], dtype=float32))
# ('real', 2.945039735197163)
# ('predict', array([4.5442834], dtype=float32))
# ('real', 2.953782411973924)
# ('predict', array([4.5376964], dtype=float32))
# ('real', 2.962823557600389)
# ('predict', array([4.5302105], dtype=float32))
# ('real', 2.9748627015937092)
# ('predict', array([4.523171], dtype=float32))
# ('real', 2.9847576639649165)
# ('predict', array([4.518252], dtype=float32))
# ('real', 2.9947208580921028)
# ('predict', array([4.512244], dtype=float32))
# ('real', 3.0048099725194026)
# ('predict', array([4.505939], dtype=float32))
# ('real', 3.0175984979328137)
# ('predict', array([4.5013413], dtype=float32))
# ('real', 3.030676671497488)
# ('predict', array([4.4965763], dtype=float32))
# ('real', 3.0413327171122537)
# ('predict', array([4.493097], dtype=float32))
# ('real', 3.05223021866281)
# ('predict', array([4.4887457], dtype=float32))
# ('real', 3.060517853281089)
# ('predict', array([4.4852123], dtype=float32))
# ('real', 3.0774630304215567)
# ('predict', array([4.481574], dtype=float32))
# ('real', 3.100740545931081)
# ('predict', array([2.846305], dtype=float32))
# ('real', 3.109706317672026)
# ('predict', array([2.3466086], dtype=float32))
# ('real', 3.1249938142414737)
# ('predict', array([2.5636635], dtype=float32))
# ('real', 3.1374846702887584)
# ('predict', array([2.7389548], dtype=float32))
# ('real', 3.156628581188902)
# ('predict', array([2.7482138], dtype=float32))
# ('real', 3.159872836600353)
# ('predict', array([2.7578843], dtype=float32))
# ('real', 3.1696732843604893)
# ('predict', array([2.7671244], dtype=float32))
# ('real', 3.182963703391094)
# ('predict', array([2.7758965], dtype=float32))
# ('real', 3.1998007969942335)
# ('predict', array([2.7821517], dtype=float32))
# ('real', 3.2274858034497735)
# ('predict', array([2.7883935], dtype=float32))
# ('real', 3.241634461171251)
# ('predict', array([2.7943363], dtype=float32))
# ('real', 3.259715120841022)
# ('predict', array([2.798243], dtype=float32))
# ('real', 3.300568694389289)
# ('predict', array([2.8030736], dtype=float32))
# ('real', 3.3192424069989657)
# ('predict', array([2.808273], dtype=float32))
# ('real', 3.3419118232043155)
# ('predict', array([2.8156612], dtype=float32))
# ('real', 3.3602640644049995)
# ('predict', array([2.824363], dtype=float32))
# ('real', 3.3841584314849595)
# ('predict', array([2.831953], dtype=float32))
# ('real', 3.402563472220077)
# ('predict', array([2.841409], dtype=float32))
# ('real', 3.418270277449801)
# ('predict', array([2.8501155], dtype=float32))
# ('real', 3.4266301335102423)
# ('predict', array([2.8610008], dtype=float32))
# ('real', 3.435107709607333)
# ('predict', array([2.8708467], dtype=float32))
# ('real', 3.445631347049887)
# ('predict', array([2.883093], dtype=float32))
# ('real', 3.455202420265747)
# ('predict', array([2.8967319], dtype=float32))
# ('real', 3.457757494594473)
# ('predict', array([2.9084442], dtype=float32))
# ('real', 3.4606123007027754)
# ('predict', array([2.9234931], dtype=float32))
# ('real', 3.4616511272227175)
# ('predict', array([2.9404142], dtype=float32))
# ('real', 3.4616781012931543)
# ('predict', array([2.9542353], dtype=float32))
# ('real', 3.4616781012931543)
# ('predict', array([2.970295], dtype=float32))
# ('real', 3.4614168836171837)
# ('predict', array([2.9873013], dtype=float32))
# ('real', 3.460819617254856)
# ('predict', array([3.0007727], dtype=float32))
# ('real', 3.4573632852860343)
# ('predict', array([3.0130286], dtype=float32))
# ('real', 3.452051784037423)
# ('predict', array([3.0279517], dtype=float32))
# ('real', 3.443088750659546)
# ('predict', array([3.0459228], dtype=float32))
# ('real', 3.4306010238858815)
# ('predict', array([3.0611253], dtype=float32))
# ('real', 3.409494754634544)
# ('predict', array([3.0791936], dtype=float32))
# ('real', 3.3839373957051)
# ('predict', array([3.0988562], dtype=float32))
# ('real', 3.357676809271056)
# ('predict', array([3.1150806], dtype=float32))
# ('real', 3.331547500699874)
# ('predict', array([3.1345494], dtype=float32))
# ('real', 3.3049135966474723)
# ('predict', array([3.1519487], dtype=float32))
# ('real', 3.279662731645225)
# ('predict', array([3.1726794], dtype=float32))
# ('real', 3.2474255935368497)
# ('predict', array([3.1948736], dtype=float32))
# ('real', 3.2007937848804726)
# ('predict', array([3.2131598], dtype=float32))
# ('real', 3.1549120039277128)
# ('predict', array([3.2349708], dtype=float32))
# ('real', 3.1109548349598173)
# ('predict', array([3.2585948], dtype=float32))
# ('real', 3.0659270852201277)
# ('predict', array([3.2780268], dtype=float32))
# ('real', 3.0190826426422723)
# ('predict', array([3.3015125], dtype=float32))
# ('real', 2.9767942477206346)
# ('predict', array([3.3218465], dtype=float32))
# ('real', 2.9332314381929905)
# ('predict', array([3.34337], dtype=float32))
# ('real', 2.8884582506358405)
# ('predict', array([3.360017], dtype=float32))
# ('real', 2.8425695764869685)
# ('predict', array([3.37531], dtype=float32))
# ('real', 2.78208178911499)
# ('predict', array([3.387529], dtype=float32))
# ('real', 2.7270001672865942)
# ('predict', array([3.3987653], dtype=float32))
# ('real', 2.677453859944999)
# ('predict', array([3.4072878], dtype=float32))
# ('real', 2.6206199050600905)
# ('predict', array([3.4161992], dtype=float32))
# ('real', 2.5632084761463942)
# ('predict', array([3.4224932], dtype=float32))
# ('real', 2.505764188772016)
# ('predict', array([3.4269674], dtype=float32))
# ('real', 2.4478039956869755)
# ('predict', array([3.429832], dtype=float32))
# ('real', 2.3903693295779935)
# ('predict', array([3.431155], dtype=float32))
# ('real', 2.3412925601859986)
# ('predict', array([3.4308991], dtype=float32))
# ('real', 2.2858867332931285)
# ('predict', array([3.429111], dtype=float32))
# ('real', 2.2321729430869084)
# ('predict', array([3.4261096], dtype=float32))
# ('real', 2.180678512362403)
# ('predict', array([3.4205925], dtype=float32))
# ('real', 2.1320988507850367)
# ('predict', array([3.412404], dtype=float32))
# ('real', 2.0861126836932304)
# ('predict', array([3.4014165], dtype=float32))
# ('real', 2.047785824768751)
# ('predict', array([3.3901193], dtype=float32))
# ('real', 2.010910174188871)
# ('predict', array([3.3742898], dtype=float32))
# ('real', 1.9702394936927041)
# ('predict', array([3.358479], dtype=float32))
# ('real', 1.9308186059094417)
# ('predict', array([3.3378778], dtype=float32))
# ('real', 1.9017573362549531)
# ('predict', array([3.3143015], dtype=float32))
# ('real', 1.863549252238824)
# ('predict', array([3.29357], dtype=float32))
# ('real', 1.8266062791037438)
# ('predict', array([3.2730126], dtype=float32))
# ('real', 1.7948550408560842)
# ('predict', array([3.2509327], dtype=float32))
# ('real', 1.7592082521802126)
# ('predict', array([3.2227309], dtype=float32))
# ('real', 1.728941417363566)
# ('predict', array([3.1929252], dtype=float32))
# ('real', 1.6993127694198944)
# ('predict', array([3.1631968], dtype=float32))
# ('real', 1.666537736709825)
# ('predict', array([3.1330342], dtype=float32))
# ('real', 1.6388707261283828)
# ('predict', array([3.107641], dtype=float32))
# ('real', 1.6083172184775616)
# ('predict', array([3.0799868], dtype=float32))
# ('real', 1.579162547021375)
# ('predict', array([3.0467293], dtype=float32))
# ('real', 1.5547455248914237)
# ('predict', array([3.0181386], dtype=float32))
# ('real', 1.5281451722965689)
# ('predict', array([2.984334], dtype=float32))
# ('real', 1.5062436129061658)
# ('predict', array([2.9544296], dtype=float32))
# ('real', 1.4827734699597803)
# ('predict', array([2.9186826], dtype=float32))
# ('real', 1.4611389900493033)
# ('predict', array([2.880454], dtype=float32))
# ('real', 1.4461194210759782)
# ('predict', array([2.841993], dtype=float32))
# ('real', 1.4277386718777276)
# ('predict', array([2.8035336], dtype=float32))
# ('real', 1.4134479330725465)
# ('predict', array([2.7720594], dtype=float32))
# ('real', 1.3990313806733061)
# ('predict', array([2.7339706], dtype=float32))
# ('real', 1.3868280611734936)
# ('predict', array([2.696768], dtype=float32))
# ('real', 1.37792663103981)
# ('predict', array([2.6560254], dtype=float32))
# ('real', 1.3698746925377028)
# ('predict', array([2.6228616], dtype=float32))
# ('real', 1.3648353230135988)
# ('predict', array([2.5878727], dtype=float32))
# ('real', 0.28731706641541555)
# ('predict', array([2.5470498], dtype=float32))
# ('real', 0.2820198791273283)
# ('predict', array([2.5056715], dtype=float32))
# ('real', 0.27448898297141133)
# ('predict', array([2.4742956], dtype=float32))
# ('real', 0.28319074774676223)
# ('predict', array([2.436394], dtype=float32))
# ('real', 0.2998661165738781)
# ('predict', array([2.3959203], dtype=float32))
# ('real', 0.3185846930016023)
# ('predict', array([2.3654537], dtype=float32))
# ('real', 0.33394765698748596)
# ('predict', array([2.3306463], dtype=float32))
# ('real', 0.34792808644063195)
# ('predict', array([2.2937922], dtype=float32))
# ('real', 0.36916904732388545)
# ('predict', array([2.266681], dtype=float32))
# ('real', 0.3999908722222645)
# ('predict', array([2.2391531], dtype=float32))
# ('real', 0.43638901401243857)
# ('predict', array([2.2072067], dtype=float32))
# ('real', 0.476161214336947)
# ('predict', array([2.183377], dtype=float32))
# ('real', 0.5215962173363978)
# ('predict', array([2.1564965], dtype=float32))
# ('real', 0.5652361833376269)
# ('predict', array([2.132186], dtype=float32))
# ('real', 0.6133910572354938)
# ('predict', array([2.1134226], dtype=float32))
# ('real', 0.6658457689547953)
# ('predict', array([2.089905], dtype=float32))
# ('real', 0.7057189660915244)
# ('predict', array([2.0652502], dtype=float32))
# ('real', 0.7394015470589196)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-8377ebd81b34> in <module>()
#     271 bug = Algorithm(ROBOT='P3DX', TARGET='Destination')
#     272
# --> 273 bug.loop()
#
# <ipython-input-13-8377ebd81b34> in loop(self)
#     178         self.action_rotating()
#     179       elif self.state == States.ROUNDING:
# --> 180         self.action_rounding()
#     181
#     182     print('Цель достигнута')
#
# <ipython-input-13-8377ebd81b34> in action_rounding(self)
#     229
#     230     # Значение угла в радианах между векторами перпендикуляра к роботу и между роботом и целью
# --> 231     angle = Utils.angle_between_vectors(perp_bot_dir, self.target_pos.minus(self.bot_pos))
#     232
#     233     # Запишем данные angle в файл
#
# /Studying/4 - 2/Диплом/workspace/assets/Utils.pyc in angle_between_vectors(a, b)
#       3 def angle_between_vectors(a, b):
#       4   a = a.unit_vector()
# ----> 5   b = b.unit_vector()
#       6   angle = math.acos(b.dot(a))
#       7   if (a.multiply(b)).z > 0:
#
# /Studying/4 - 2/Диплом/workspace/assets/Vector.pyc in unit_vector(self)
#      33
#      34   def unit_vector(self):
# ---> 35     n = 1.0 / self.length()
#      36     return Vector3(x=self.x * n, y=self.y * n, z=self.z * n)
#
# ZeroDivisionError: float division by zero
