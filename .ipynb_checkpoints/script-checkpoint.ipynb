# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

# %%
training_set = pd.read_csv('data.csv')
training_set = training_set.iloc[:,1:2].values
plt.plot(training_set, label = ' ')
plt.show()

# %%
def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

sc = MinMaxScaler()
training_data = sc.fit_transform(training_set)
seq_length = 4
x, y = sliding_windows(training_data, seq_length)

train_size = int(len(y) * 0.5)
test_size = len(y) - train_size

dataX = Variable(torch.Tensor(np.array(x)))
dataY = Variable(torch.Tensor(np.array(y)))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])))

testX = Variable(torch.Tensor(np.array(x[train_size:len(x)])))
testY = Variable(torch.Tensor(np.array(y[train_size:len(y)])))

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %%
num_epochs = 4000
learning_rate = 0.01

input_size = 1
hidden_size = 2
num_layers = 1

num_classes = 1

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    
    # obtain the loss function
    loss = criterion(outputs, trainY)
    
    loss.backward()
    
    optimizer.step()

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)

plt.axvline(x=train_size, c='r', linestyle='--')

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('Time-Series Prediction')
plt.show()

# %%
import time
import sys
import numpy as np
import vrep
from assets import *

# %%
class Algorithm:
  def __init__(self, ROBOT, TARGET):
    self.state = States.MOVING

    self.MIN_DETECTION_DIST = 0
    self.MAX_DETECTION_DIST = 1

    self.ROBOT = ROBOT
    self.TARGET = TARGET
    self.SPEED = 1.5
    self.INDENT_DIST = 0.5
    self.ar = []
    self.SLEEP_TIME = 0.2
    self.PI = math.pi
    self.bot_dir = None
    self.bot_pos = None
    self.bot_euler_angles = None

    self.target_pos = None
    self.target_dir = np.zeros(3)

    self.detect = np.zeros(16)

    self._init_client_id()
    self._init_robot_handle()
    self._init_sensor_handles()
    self._init_wheels_handles()
    self._init_target_handle()

    self.obstacle_dist_stab_PID = PIDController(50)
    self.obstacle_follower_PID = PIDController(50)
    self.obstacle_dist_stab_PID.set_coefficients(2, 0, 0.5)
    self.obstacle_follower_PID.set_coefficients(2, 0, 0)

    self.min_dist_to_target = None

    self.print_info()


  def _init_client_id(self):
    vrep.simxFinish(-1)

    self.client_id = vrep.simxStart('127.0.0.1', 19999, True, True, 5000, 5)

    if self.client_id != -1:
      print('')
    else:
      sys.exit('')


  def _init_robot_handle(self):
    error_code, self.bot_handle = vrep.simxGetObjectHandle(self.client_id, self.ROBOT, vrep.simx_opmode_oneshot_wait)


  def _init_sensor_handles(self):
    self.sensor_handles = []

    for x in range(0, 16):
      error_code, sensor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_ultrasonicSensor' + str(x + 1), vrep.simx_opmode_oneshot_wait)
      self.sensor_handles.append(sensor_handle)
      vrep.simxReadProximitySensor(self.client_id, sensor_handle, vrep.simx_opmode_streaming)


  def _init_wheels_handles(self):
    error_code, self.left_motor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_leftMotor', vrep.simx_opmode_oneshot_wait)
    error_code, self.right_motor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_rightMotor', vrep.simx_opmode_oneshot_wait)


  def _init_target_handle(self):
    error_code, self.target_handle = vrep.simxGetObjectHandle(self.client_id, self.TARGET, vrep.simx_opmode_oneshot_wait)


  def _init_values(self):
    # Инициализация значений цели и робота
    error_code, _ = vrep.simxGetObjectPosition(self.client_id, self.target_handle, -1, vrep.simx_opmode_oneshot)
    error_code, _ = vrep.simxGetObjectPosition(self.client_id, self.bot_handle, -1, vrep.simx_opmode_oneshot)
    error_code, _ = vrep.simxGetObjectOrientation(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)


  def read_values(self):
    # Чтение значений позиции цели
    error_code, target_pos = vrep.simxGetObjectPosition(self.client_id, self.target_handle, -1, vrep.simx_opmode_streaming)
    self.target_pos = Vector3(x=target_pos[0], y=target_pos[1], z=0)

    # Чтение значений позиции робота
    error_code, bot_pos = vrep.simxGetObjectPosition(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)
    self.bot_pos = Vector3(x=bot_pos[0], y=bot_pos[1], z=0)

    # Чтение значений углов Эйлера робота
    error_code, bot_euler_angles = vrep.simxGetObjectOrientation(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)
    self.bot_euler_angles = Vector3(x=0, y=0, z=bot_euler_angles[2])


  def stop_move(self):
    # Остановка движения робота
    error_code = vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  0, vrep.simx_opmode_streaming)
    error_code = vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, 0, vrep.simx_opmode_streaming)


  def read_from_sensors(self):
    # Чтение значений с сенсоров
    for i in range(0, 16):
      error_code, detection_state, detected_point, detected_object_handle, detected_surface_normal_vector = vrep.simxReadProximitySensor(self.client_id, self.sensor_handles[i], vrep.simx_opmode_streaming)

      # Значение дистанции до препятствия
      dist = math.sqrt(detected_point[0] ** 2 + detected_point[1] ** 2 + detected_point[2] ** 2)

      # Присвоение значений датчиков: чем больше значение, тем ближе к конкретному датчику препятствие
      if dist < self.MIN_DETECTION_DIST:
        self.detect[i] = self.MIN_DETECTION_DIST
      elif dist > self.MAX_DETECTION_DIST or detection_state == False:
        self.detect[i] = self.MAX_DETECTION_DIST
      else:
        self.detect[i] = self.MAX_DETECTION_DIST - ((dist - self.MAX_DETECTION_DIST) / (self.MIN_DETECTION_DIST - self.MAX_DETECTION_DIST))


  def print_info(self):
    print('Цель: ' + self.TARGET)
    print('Робот: ' + self.ROBOT)
    print('Скорость: ' + str(self.SPEED))


  def tick(self):
    # Задержка программы
    time.sleep(self.SLEEP_TIME)


  def loop(self):
    self._init_values()
    self.read_values()
    i = 0
    # Основной цикл программы
    while Utils.distance_between_points(self.bot_pos, self.target_pos) > 0.4 or Utils.distance_between_points(self.bot_pos, self.target_pos) == 0:
      self.tick()
      # print(Utils.distance_between_points(self.bot_pos, self.target_pos))
      i = i+1
      # Останавливаем движение и читаем данные робота и цели
      self.stop_move()
      self.read_values()

      # Получаем данные с сенсоров
      self.read_from_sensors()

      # Инициализируем новый кватернион
      q_rot = Quaternion()
      # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
      q_rot.set_from_vector(self.bot_euler_angles.z, Vector3(0, 0, 1))
      # Присваиваем вектору робота значения поворота вектора кватернионом
      self.bot_dir = q_rot.rotate(Vector3(1, 0, 0))

      # Проверка текущего состояния и выполнение соответствующей функции
      if self.state == States.MOVING:
        self.action_moving()
      elif self.state == States.ROTATING:
        self.action_rotating()
      elif self.state == States.ROUNDING:
        self.action_rounding()

    print('Цель достигнута')
    self.stop_move()


  def action_moving(self):
    # Если робот оказалася близко к препятствию, объезжаем это препятствие, иначе продолжаем движение до цели
    if (self.detect[4] + self.detect[5])/2 < self.INDENT_DIST:
      # Инициализируем новый кватернион
      q = Quaternion()
      # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
      q.set_from_vector(self.PI/2, Vector3(0, 0, 1))
      # Присваиваем вектору цели значения поворота вектора направления робота кватернионом
      self.target_dir = q.rotate(self.bot_dir)
      # Переключаем состояние
      self.state = States.ROTATING
    else:
      # Значение угла в радианах между векторами направления движения робота и между роботом и целью
      angle = Utils.angle_between_vectors(self.bot_dir, self.target_pos.minus(self.bot_pos))

      # Корректируем движение робота до прямолинейного до цели, если необходимо
      if math.fabs(angle) > self.PI/180:
        vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  self.SPEED + angle, vrep.simx_opmode_streaming)
        vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED - angle, vrep.simx_opmode_streaming)
      else:
        vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  self.SPEED, vrep.simx_opmode_streaming)
        vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED, vrep.simx_opmode_streaming)


  def action_rotating(self):
    # Значение угла в радианах между векторами направления движения робота и цели
    angle = Utils.angle_between_vectors(self.bot_dir, self.target_dir)

    # Поворачиваем робота вокруг своей оси, если необходимо, иначе переключаем состояние
    if math.fabs(angle) > 5 * self.PI/180:
      vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle, angle, vrep.simx_opmode_streaming)
      vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, -angle, vrep.simx_opmode_streaming)
    else:
      self.state = States.ROUNDING


  def action_rounding(self):
    # Инициализация нового кватерниона
    q = Quaternion()
    # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
    q.set_from_vector(self.PI/2, Vector3(0, 0, 1))
    # Присваиваем перпендикуляру вектора робота значения поворота вектора направления робота кватернионом
    perp_bot_dir = q.rotate(self.bot_dir)

    # Значение угла в радианах между векторами перпендикуляра к роботу и между роботом и целью
    angle = Utils.angle_between_vectors(perp_bot_dir, self.target_pos.minus(self.bot_pos))
    #==============================================================================
    f1 = open('f1.txt', 'a')
    z = str(angle)
    f1.write(z+'\n')
    self.ar.append(angle)
    #print(len(self.ar))
    # Текущая дистанция до цели
    current_dist_to_target1 = Utils.distance_between_points(self.bot_pos, self.target_pos)
    current_dist_to_target = data_predict[len(self.ar)]
    print('predict',current_dist_to_target)
    print('real', current_dist_to_target1)
    #==============================================================================
    f2 = open('f2.txt', 'a')
    m = str(current_dist_to_target)
    f2.write(m+'\n')

    # Если минимальное значение дистанции до цели меньше, чем текущее, то присваиваем минимальному значению текущее
    if self.min_dist_to_target == None or self.min_dist_to_target <= current_dist_to_target:
      self.min_dist_to_target = current_dist_to_target
    # Прекращаем объезд препятствия
    elif math.fabs(angle) < 5.0 / 180 * self.PI:
      self.state = States.MOVING
      return

    # Разница между значениями двух крайних справа датчиков
    delta = self.detect[7] - self.detect[8]

    # Устанавливаем расстояние до препятствия
    obstacle_dist = min([self.detect[7], self.detect[8]]) - self.INDENT_DIST

    obstacle_dist_stab = self.obstacle_dist_stab_PID.output(obstacle_dist)
    obstacle_follower = self.obstacle_follower_PID.output(delta)
  
    vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle, self.SPEED + obstacle_follower + obstacle_dist_stab - (1 - (self.detect[4] + self.detect[5])/2), vrep.simx_opmode_streaming)
    vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED - obstacle_follower - obstacle_dist_stab + (1 - (self.detect[4] + self.detect[5])/2), vrep.simx_opmode_streaming)


bug = Algorithm(ROBOT='P3DX', TARGET='Destination')

bug.loop()
# Out:
# Цель: Destination
# Робот: P3DX
# Скорость: 1.5
# ('predict', array([7.839345], dtype=float32))
# ('real', 7.888573245721858)
# ('predict', array([7.8559694], dtype=float32))
# ('real', 7.8898921070566015)
# ('predict', array([7.876195], dtype=float32))
# ('real', 7.897693391395438)
# ('predict', array([7.896493], dtype=float32))
# ('real', 7.908993239503955)
# ('predict', array([7.910406], dtype=float32))
# ('real', 7.918459133311461)
# ('predict', array([7.9218416], dtype=float32))
# ('real', 7.926325693741153)
# ('predict', array([7.9304285], dtype=float32))
# ('real', 7.930241707704582)
# ('predict', array([7.934726], dtype=float32))
# ('real', 7.930730243073251)
# ('predict', array([7.933421], dtype=float32))
# ('real', 7.927797702606339)
# ('predict', array([7.925463], dtype=float32))
# ('real', 7.919656034485191)
# ('predict', array([7.910906], dtype=float32))
# ('real', 7.910359143650786)
# ('predict', array([7.8992796], dtype=float32))
# ('real', 7.900984698589857)
# ('predict', array([7.8902473], dtype=float32))
# ('real', 7.896812936602093)
# ('predict', array([7.8838687], dtype=float32))
# ('real', 7.89042652083944)
# ('predict', array([7.8782916], dtype=float32))
# ('real', 7.884444537289029)
# ('predict', array([7.8724246], dtype=float32))
# ('real', 7.878951944281998)
# ('predict', array([7.867512], dtype=float32))
# ('real', 7.874278948568979)
# ('predict', array([7.8634534], dtype=float32))
# ('real', 7.868683232362864)
# ('predict', array([7.859239], dtype=float32))
# ('real', 7.864656303780767)
# ('predict', array([7.8557005], dtype=float32))
# ('real', 7.8594987426302)
# ('predict', array([7.852744], dtype=float32))
# ('real', 7.855316601164142)
# ('predict', array([7.849666], dtype=float32))
# ('real', 7.851829221501344)
# ('predict', array([7.846689], dtype=float32))
# ('real', 7.848085290534763)
# ('predict', array([7.844498], dtype=float32))
# ('real', 7.84440824011281)
# ('predict', array([7.843044], dtype=float32))
# ('real', 7.84113228161389)
# ('predict', array([7.841056], dtype=float32))
# ('real', 7.838518839976309)
# ('predict', array([7.8390727], dtype=float32))
# ('real', 7.835630667481477)
# ('predict', array([7.8373394], dtype=float32))
# ('real', 7.832533274288949)
# ('predict', array([7.8363976], dtype=float32))
# ('real', 7.829328366769266)
# ('predict', array([7.8353295], dtype=float32))
# ('real', 7.827518061291141)
# ('predict', array([7.8342423], dtype=float32))
# ('real', 7.825285163455064)
# ('predict', array([7.8339286], dtype=float32))
# ('real', 7.8229595233287945)
# ('predict', array([7.833651], dtype=float32))
# ('real', 7.821099615375702)
# ('predict', array([7.833705], dtype=float32))
# ('real', 7.819857603603139)
# ('predict', array([7.833582], dtype=float32))
# ('real', 7.8179002320410556)
# ('predict', array([7.8340077], dtype=float32))
# ('real', 7.816851305745235)
# ('predict', array([7.834506], dtype=float32))
# ('real', 7.815914858153105)
# ('predict', array([7.8354015], dtype=float32))
# ('real', 7.8147400461092555)
# ('predict', array([7.8363657], dtype=float32))
# ('real', 7.8143498595260406)
# ('predict', array([7.8377614], dtype=float32))
# ('real', 7.814125699043927)
# ('predict', array([7.8391623], dtype=float32))
# ('real', 7.813634235378833)
# ('predict', array([7.8408713], dtype=float32))
# ('real', 7.8137396210047285)
# ('predict', array([7.842615], dtype=float32))
# ('real', 7.813985131340051)
# ('predict', array([7.8449693], dtype=float32))
# ('real', 7.81438315455799)
# ('predict', array([7.847682], dtype=float32))
# ('real', 7.814497891002935)
# ('predict', array([7.8509507], dtype=float32))
# ('real', 7.815374297559717)
# ('predict', array([7.853714], dtype=float32))
# ('real', 7.81667714237457)
# ('predict', array([7.8567357], dtype=float32))
# ('real', 7.817867283257226)
# ('predict', array([7.859917], dtype=float32))
# ('real', 7.818952135820279)
# ('predict', array([7.8627987], dtype=float32))
# ('real', 7.820567009568849)
# ('predict', array([7.8656263], dtype=float32))
# ('real', 7.822193257623146)
# ('predict', array([7.8691754], dtype=float32))
# ('real', 7.824156117746855)
# ('predict', array([7.872533], dtype=float32))
# ('real', 7.826781625782709)
# ('predict', array([7.876471], dtype=float32))
# ('real', 7.829984924991421)
# ('predict', array([7.880822], dtype=float32))
# ('real', 7.8325609254825705)
# ('predict', array([7.885534], dtype=float32))
# ('real', 7.835202213144734)
# ('predict', array([7.8897386], dtype=float32))
# ('real', 7.838492461846713)
# ('predict', array([7.894719], dtype=float32))
# ('real', 7.84134362303743)
# ('predict', array([7.900241], dtype=float32))
# ('real', 7.8443226908758135)
# ('predict', array([7.905259], dtype=float32))
# ('real', 7.848066841182874)
# ('predict', array([7.91104], dtype=float32))
# ('real', 7.8520167194610435)
# ('predict', array([7.9176702], dtype=float32))
# ('real', 7.855477734553197)
# ('predict', array([7.92351], dtype=float32))
# ('real', 7.859865248900284)
# ('predict', array([7.9292965], dtype=float32))
# ('real', 7.863714972252422)
# ('predict', array([7.9354095], dtype=float32))
# ('real', 7.86865065710575)
# ('predict', array([7.9428043], dtype=float32))
# ('real', 7.87379402303208)
# ('predict', array([7.9453487], dtype=float32))
# ('real', 7.878292251142498)
# ('predict', array([7.940521], dtype=float32))
# ('real', 7.883959763717771)
# ('predict', array([7.9313207], dtype=float32))
# ('real', 7.88886335731104)
# ('predict', array([7.921655], dtype=float32))
# ('real', 7.895009380195075)
# ('predict', array([7.9122133], dtype=float32))
# ('real', 7.900529135431879)
# ('predict', array([7.9037676], dtype=float32))
# ('real', 7.9071033250371014)
# ('predict', array([7.893145], dtype=float32))
# ('real', 7.9113583383916595)
# ('predict', array([7.879383], dtype=float32))
# ('real', 7.91710330220052)
# ('predict', array([7.8622885], dtype=float32))
# ('real', 7.9235026818863785)
# ('predict', array([7.84233], dtype=float32))
# ('real', 7.927471829348869)
# ('predict', array([7.8196383], dtype=float32))
# ('real', 7.929552169338346)
# ('predict', array([7.798244], dtype=float32))
# ('real', 7.929612204186112)
# ('predict', array([7.7761955], dtype=float32))
# ('real', 7.927062968418922)
# ('predict', array([7.7484665], dtype=float32))
# ('real', 7.921301797329277)
# ('predict', array([7.721926], dtype=float32))
# ('real', 7.913392443630301)
# ('predict', array([7.6937604], dtype=float32))
# ('real', 7.903170404672426)
# ('predict', array([7.6609917], dtype=float32))
# ('real', 7.889339751629802)
# ('predict', array([7.6307807], dtype=float32))
# ('real', 7.874525651675592)
# ('predict', array([7.5958176], dtype=float32))
# ('real', 7.861739445354205)
# ('predict', array([7.5574017], dtype=float32))
# ('real', 7.848282912202011)
# ('predict', array([7.5167327], dtype=float32))
# ('real', 7.832107081018273)
# ('predict', array([7.4819546], dtype=float32))
# ('real', 7.815380968934433)
# ('predict', array([7.4414945], dtype=float32))
# ('real', 7.792428947297503)
# ('predict', array([7.398065], dtype=float32))
# ('real', 7.771190082906618)
# ('predict', array([7.361026], dtype=float32))
# ('real', 7.743158792829962)
# ('predict', array([7.3200393], dtype=float32))
# ('real', 7.718059603712059)
# ('predict', array([7.2761574], dtype=float32))
# ('real', 7.686078079967295)
# ('predict', array([7.231723], dtype=float32))
# ('real', 7.65235758802575)
# ('predict', array([7.19543], dtype=float32))
# ('real', 7.6171057213088)
# ('predict', array([7.153901], dtype=float32))
# ('real', 7.586557317372617)
# ('predict', array([7.1168227], dtype=float32))
# ('real', 7.548705686272034)
# ('predict', array([7.0741277], dtype=float32))
# ('real', 7.516194164733131)
# ('predict', array([7.0372777], dtype=float32))
# ('real', 7.4761629517572015)
# ('predict', array([7.016947], dtype=float32))
# ('real', 7.442057992905707)
# ('predict', array([6.993219], dtype=float32))
# ('real', 7.404478748894174)
# ('predict', array([6.957099], dtype=float32))
# ('real', 7.36297451782859)
# ('predict', array([6.9107385], dtype=float32))
# ('real', 7.321198035352029)
# ('predict', array([6.8727026], dtype=float32))
# ('real', 7.286093424400914)
# ('predict', array([6.831943], dtype=float32))
# ('real', 7.2436281465977865)
# ('predict', array([6.7903943], dtype=float32))
# ('real', 7.2010278142731625)
# ('predict', array([6.7569003], dtype=float32))
# ('real', 7.158183900456541)
# ('predict', array([6.72074], dtype=float32))
# ('real', 7.1152295615755845)
# ('predict', array([6.6900086], dtype=float32))
# ('real', 7.072318312419551)
# ('predict', array([6.655281], dtype=float32))
# ('real', 7.036461538688093)
# ('predict', array([6.626697], dtype=float32))
# ('real', 6.996833473010335)
# ('predict', array([6.594586], dtype=float32))
# ('real', 6.960890642211733)
# ('predict', array([6.562993], dtype=float32))
# ('real', 6.921889258779417)
# ('predict', array([6.5387316], dtype=float32))
# ('real', 6.886654339147094)
# ('predict', array([6.5179653], dtype=float32))
# ('real', 6.84520872697093)
# ('predict', array([6.4929843], dtype=float32))
# ('real', 6.804600783511135)
# ('predict', array([6.4725747], dtype=float32))
# ('real', 6.77155963669089)
# ('predict', array([6.451609], dtype=float32))
# ('real', 6.733398087587834)
# ('predict', array([6.432232], dtype=float32))
# ('real', 6.702417584647109)
# ('predict', array([6.4153767], dtype=float32))
# ('real', 6.669581243088227)
# ('predict', array([6.4043007], dtype=float32))
# ('real', 6.635034764799827)
# ('predict', array([6.3931937], dtype=float32))
# ('real', 6.607437436913123)
# ('predict', array([6.385534], dtype=float32))
# ('real', 6.578520204118336)
# ('predict', array([6.378384], dtype=float32))
# ('real', 6.553620383821103)
# ('predict', array([6.3740063], dtype=float32))
# ('real', 6.532446197239782)
# ('predict', array([6.3701563], dtype=float32))
# ('real', 6.505966561762041)
# ('predict', array([5.793106], dtype=float32))
# ('real', 6.4814510565235555)
# ('predict', array([5.687064], dtype=float32))
# ('real', 6.462630102086134)
# ('predict', array([5.767393], dtype=float32))
# ('real', 6.4422184568802345)
# ('predict', array([5.844427], dtype=float32))
# ('real', 6.424293223623309)
# ('predict', array([5.8561225], dtype=float32))
# ('real', 6.408757693256659)
# ('predict', array([5.869349], dtype=float32))
# ('real', 6.39784543013387)
# ('predict', array([5.8831115], dtype=float32))
# ('real', 6.387118850605506)
# ('predict', array([5.897924], dtype=float32))
# ('real', 6.378789916599014)
# ('predict', array([5.912767], dtype=float32))
# ('real', 6.373565410593236)
# ('predict', array([5.924507], dtype=float32))
# ('real', 6.368673232657774)
# ('predict', array([5.9361687], dtype=float32))
# ('real', 5.851809863504645)
# ('predict', array([5.9486046], dtype=float32))
# ('real', 5.848898263221663)
# ('predict', array([5.958352], dtype=float32))
# ('real', 5.8405869908694825)
# ('predict', array([5.9688487], dtype=float32))
# ('real', 5.843652433405477)
# ('predict', array([5.979328], dtype=float32))
# ('real', 5.849551599708932)
# ('predict', array([5.9894814], dtype=float32))
# ('real', 5.854926963451424)
# ('predict', array([5.997494], dtype=float32))
# ('real', 5.862690474032172)
# ('predict', array([6.0073028], dtype=float32))
# ('real', 5.870598700002788)
# ('predict', array([6.018172], dtype=float32))
# ('real', 5.881820844587655)
# ('predict', array([6.0296364], dtype=float32))
# ('real', 5.893373379845418)
# ('predict', array([6.039317], dtype=float32))
# ('real', 5.9048530063121785)
# ('predict', array([6.0513988], dtype=float32))
# ('real', 5.919075725276226)
# ('predict', array([6.064676], dtype=float32))
# ('real', 5.933512952311168)
# ('predict', array([6.07582], dtype=float32))
# ('real', 5.945260200761622)
# ('predict', array([6.088897], dtype=float32))
# ('real', 5.958565585146842)
# ('predict', array([6.1003585], dtype=float32))
# ('real', 5.969142783938258)
# ('predict', array([6.113873], dtype=float32))
# ('real', 5.9811191127474075)
# ('predict', array([6.1278167], dtype=float32))
# ('real', 5.9907113742249365)
# ('predict', array([6.1403985], dtype=float32))
# ('real', 6.0018037531653174)
# ('predict', array([6.1511116], dtype=float32))
# ('real', 6.012762266721986)
# ('predict', array([6.164378], dtype=float32))
# ('real', 6.0238080549843875)
# ('predict', array([6.1785846], dtype=float32))
# ('real', 6.03319481598159)
# ('predict', array([6.1902175], dtype=float32))
# ('real', 6.044837692322977)
# ('predict', array([6.2039814], dtype=float32))
# ('real', 6.0549509716957175)
# ('predict', array([6.2189455], dtype=float32))
# ('real', 6.067657310290852)
# ('predict', array([6.231493], dtype=float32))
# ('real', 6.07865981587855)
# ('predict', array([6.24621], dtype=float32))
# ('real', 6.092255222799631)
# ('predict', array([6.259257], dtype=float32))
# ('real', 6.103861102604347)
# ('predict', array([6.274897], dtype=float32))
# ('real', 6.116791896236815)
# ('predict', array([6.2913756], dtype=float32))
# ('real', 6.128687561125045)
# ('predict', array([6.3049946], dtype=float32))
# ('real', 6.143048599210701)
# ('predict', array([6.320823], dtype=float32))
# ('real', 6.157496402693702)
# ('predict', array([6.337842], dtype=float32))
# ('real', 6.169558856852196)
# ('predict', array([6.3518643], dtype=float32))
# ('real', 6.184048643056881)
# ('predict', array([6.3681636], dtype=float32))
# ('real', 6.196220244356898)
# ('predict', array([6.3856826], dtype=float32))
# ('real', 6.210930576799154)
# ('predict', array([6.400174], dtype=float32))
# ('real', 6.223313211618082)
# ('predict', array([6.4105635], dtype=float32))
# ('real', 6.2358939487235245)
# ('predict', array([6.4274106], dtype=float32))
# ('real', 6.249963815718602)
# ('predict', array([6.44662], dtype=float32))
# ('real', 6.263011515902677)
# ('predict', array([6.4622846], dtype=float32))
# ('real', 6.278980535551458)
# ('predict', array([6.4767733], dtype=float32))
# ('real', 6.292509852433243)
# ('predict', array([6.4958296], dtype=float32))
# ('real', 6.309070357654389)
# ('predict', array([6.517097], dtype=float32))
# ('real', 6.323048953149624)
# ('predict', array([6.534756], dtype=float32))
# ('real', 6.340045764240851)
# ('predict', array([6.554989], dtype=float32))
# ('real', 6.3543702313024735)
# ('predict', array([6.576254], dtype=float32))
# ('real', 6.370218617689868)
# ('predict', array([6.593309], dtype=float32))
# ('real', 6.384846048620953)
# ('predict', array([6.612194], dtype=float32))
# ('real', 6.399605007929829)
# ('predict', array([6.631702], dtype=float32))
# ('real', 6.415819230326676)
# ('predict', array([6.6478777], dtype=float32))
# ('real', 6.430823823861617)
# ('predict', array([6.6632733], dtype=float32))
# ('real', 6.449105981164067)
# ('predict', array([6.683177], dtype=float32))
# ('real', 6.464666261554936)
# ('predict', array([6.700915], dtype=float32))
# ('real', 6.4839669025732105)
# ('predict', array([6.721243], dtype=float32))
# ('real', 6.500849914516533)
# ('predict', array([6.7388487], dtype=float32))
# ('real', 6.519795117133182)
# ('predict', array([6.7558193], dtype=float32))
# ('real', 6.537373110148691)
# ('predict', array([6.776768], dtype=float32))
# ('real', 6.558386330690612)
# ('predict', array([6.795489], dtype=float32))
# ('real', 6.57572719350994)
# ('predict', array([6.8168488], dtype=float32))
# ('real', 6.596107010198996)
# ('predict', array([6.8393245], dtype=float32))
# ('real', 6.615918551896598)
# ('predict', array([6.858172], dtype=float32))
# ('real', 6.632320941762209)
# ('predict', array([6.8756013], dtype=float32))
# ('real', 6.652301249683833)
# ('predict', array([6.897541], dtype=float32))
# ('real', 6.669185323955029)
# ('predict', array([6.9174604], dtype=float32))
# ('real', 6.687886767624852)
# ('predict', array([6.9371505], dtype=float32))
# ('real', 6.705166378137409)
# ('predict', array([6.956419], dtype=float32))
# ('real', 6.7261217235507615)
# ('predict', array([6.969467], dtype=float32))
# ('real', 6.747332454911603)
# ('predict', array([6.9786496], dtype=float32))
# ('real', 6.765206892025993)
# ('predict', array([6.9857874], dtype=float32))
# ('real', 6.7868674797804)
# ('predict', array([6.9954433], dtype=float32))
# ('real', 6.805096573289844)
# ('predict', array([7.00548], dtype=float32))
# ('real', 6.827187080672408)
# ('predict', array([7.0128303], dtype=float32))
# ('real', 6.8458077449296235)
# ('predict', array([7.018891], dtype=float32))
# ('real', 6.868305412203025)
# ('predict', array([7.0222454], dtype=float32))
# ('real', 6.887093487526963)
# ('predict', array([7.0217834], dtype=float32))
# ('real', 6.910027296749711)
# ('predict', array([7.0173974], dtype=float32))
# ('real', 6.928253266063271)
# ('predict', array([7.009548], dtype=float32))
# ('real', 6.945414169900811)
# ('predict', array([7.000861], dtype=float32))
# ('real', 6.9589389837547735)
# ('predict', array([6.9892683], dtype=float32))
# ('real', 6.9702671878666305)
# ('predict', array([6.975649], dtype=float32))
# ('real', 6.979663979433664)
# ('predict', array([6.960614], dtype=float32))
# ('real', 6.989762944312025)
# ('predict', array([6.9468966], dtype=float32))
# ('real', 6.9985118626684395)
# ('predict', array([6.9292145], dtype=float32))
# ('real', 7.008008836002554)
# ('predict', array([6.9082365], dtype=float32))
# ('real', 7.015774992529001)
# ('predict', array([6.8848147], dtype=float32))
# ('real', 7.020472778943587)
# ('predict', array([6.8635507], dtype=float32))
# ('real', 7.022373981103739)
# ('predict', array([6.836479], dtype=float32))
# ('real', 7.020829858692165)
# ('predict', array([6.8051953], dtype=float32))
# ('real', 7.01722757389731)
# ('predict', array([6.77194], dtype=float32))
# ('real', 7.010388502868402)
# ('predict', array([6.7441554], dtype=float32))
# ('real', 7.001403359345277)
# ('predict', array([6.711551], dtype=float32))
# ('real', 6.992437268540865)
# ('predict', array([6.6762514], dtype=float32))
# ('real', 6.981086306156551)
# ('predict', array([6.640162], dtype=float32))
# ('real', 6.96957613437018)
# ('predict', array([6.6105423], dtype=float32))
# ('real', 6.9536899057578285)
# ('predict', array([6.5749936], dtype=float32))
# ('real', 6.938825270578565)
# ('predict', array([6.5363145], dtype=float32))
# ('real', 6.9186618096183325)
# ('predict', array([6.4966516], dtype=float32))
# ('real', 6.899943870694161)
# ('predict', array([6.464329], dtype=float32))
# ('real', 6.877494601203253)
# ('predict', array([6.425584], dtype=float32))
# ('real', 6.8506123727598585)
# ('predict', array([6.383548], dtype=float32))
# ('real', 6.826062983641055)
# ('predict', array([6.3486767], dtype=float32))
# ('real', 6.794806819384519)
# ('predict', array([6.3081546], dtype=float32))
# ('real', 6.767784272236846)
# ('predict', array([6.264614], dtype=float32))
# ('real', 6.73729486610116)
# ('predict', array([6.2289186], dtype=float32))
# ('real', 6.703187156950315)
# ('predict', array([6.1876984], dtype=float32))
# ('real', 6.674061920544985)
# ('predict', array([6.1518826], dtype=float32))
# ('real', 6.641395488414118)
# ('predict', array([6.109627], dtype=float32))
# ('real', 6.60482961614248)
# ('predict', array([6.065921], dtype=float32))
# ('real', 6.5737260843213)
# ('predict', array([6.0225687], dtype=float32))
# ('real', 6.538810151121122)
# ('predict', array([5.9885707], dtype=float32))
# ('real', 6.4996585134775975)
# ('predict', array([5.9486585], dtype=float32))
# ('real', 6.466582152838471)
# ('predict', array([5.906866], dtype=float32))
# ('real', 6.429423518742306)
# ('predict', array([5.86632], dtype=float32))
# ('real', 6.395143104168786)
# ('predict', array([5.834959], dtype=float32))
# ('real', 6.353401493416441)
# ('predict', array([5.7983108], dtype=float32))
# ('real', 6.3112084244378055)
# ('predict', array([5.7607837], dtype=float32))
# ('real', 6.2757201422359445)
# ('predict', array([5.7317376], dtype=float32))
# ('real', 6.236310523072004)
# ('predict', array([5.698826], dtype=float32))
# ('real', 6.193104091904642)
# ('predict', array([5.6656756], dtype=float32))
# ('real', 6.1571087272985014)
# ('predict', array([5.640554], dtype=float32))
# ('real', 6.1175797844601805)
# ('predict', array([5.6129947], dtype=float32))
# ('real', 6.0817416899286485)
# ('predict', array([5.5856123], dtype=float32))
# ('real', 6.039140211781331)
# ('predict', array([5.5647964], dtype=float32))
# ('real', 6.003808342625412)
# ('predict', array([5.54376], dtype=float32))
# ('real', 5.965432462264469)
# ('predict', array([5.524676], dtype=float32))
# ('real', 5.924347054522973)
# ('predict', array([5.501774], dtype=float32))
# ('real', 5.8906447868496565)
# ('predict', array([5.478999], dtype=float32))
# ('real', 5.851059077736775)
# ('predict', array([5.4610133], dtype=float32))
# ('real', 5.818804330884216)
# ('predict', array([5.439812], dtype=float32))
# ('real', 5.7811253899846)
# ('predict', array([5.4218383], dtype=float32))
# ('real', 5.745044336646262)
# ('predict', array([5.400463], dtype=float32))
# ('real', 5.715819527413102)
# ('predict', array([5.3785367], dtype=float32))
# ('real', 5.682532360670818)
# ('predict', array([5.3607936], dtype=float32))
# ('real', 5.651011161187942)
# ('predict', array([5.3397584], dtype=float32))
# ('real', 5.62645003917275)
# ('predict', array([5.3178935], dtype=float32))
# ('real', 5.603026425717421)
# ('predict', array([5.300177], dtype=float32))
# ('real', 5.580787230035107)
# ('predict', array([5.279227], dtype=float32))
# ('real', 5.555418700999684)
# ('predict', array([5.257454], dtype=float32))
# ('real', 5.531467049896514)
# ('predict', array([5.239883], dtype=float32))
# ('real', 5.5121617453230085)
# ('predict', array([5.219088], dtype=float32))
# ('real', 5.489488942196162)
# ('predict', array([5.19752], dtype=float32))
# ('real', 5.467465325525286)
# ('predict', array([5.180151], dtype=float32))
# ('real', 5.44938231409117)
# ('predict', array([5.159632], dtype=float32))
# ('real', 5.4313616268211895)
# ('predict', array([5.142243], dtype=float32))
# ('real', 5.4134993116411945)
# ('predict', array([5.1216197], dtype=float32))
# ('real', 5.392271525874331)
# ('predict', array([5.10065], dtype=float32))
# ('real', 5.374769440923069)
# ('predict', array([5.0837927], dtype=float32))
# ('real', 5.353701101499371)
# ('predict', array([5.065836], dtype=float32))
# ('real', 5.336229059619298)
# ('predict', array([5.049249], dtype=float32))
# ('real', 5.317111964387389)
# ('predict', array([5.030963], dtype=float32))
# ('real', 5.299584220825454)
# ('predict', array([5.010789], dtype=float32))
# ('real', 5.2785614719073015)
# ('predict', array([4.9907217], dtype=float32))
# ('real', 5.261200171606384)
# ('predict', array([4.974864], dtype=float32))
# ('real', 5.240324797406224)
# ('predict', array([4.956074], dtype=float32))
# ('real', 5.223099897440249)
# ('predict', array([4.9367642], dtype=float32))
# ('real', 5.205840464373967)
# ('predict', array([4.9213333], dtype=float32))
# ('real', 5.185231871090135)
# ('predict', array([4.9031854], dtype=float32))
# ('real', 5.1681767537641)
# ('predict', array([4.8879704], dtype=float32))
# ('real', 5.151166109924171)
# ('predict', array([4.8700347], dtype=float32))
# ('real', 5.130893343597133)
# ('predict', array([4.8552384], dtype=float32))
# ('real', 5.1141712356757125)
# ('predict', array([4.8393674], dtype=float32))
# ('real', 5.0941392838050445)
# ('predict', array([4.82234], dtype=float32))
# ('real', 5.075923878819)
# ('predict', array([4.8084874], dtype=float32))
# ('real', 5.059466938007467)
# ('predict', array([4.791957], dtype=float32))
# ('real', 5.041629801349981)
# ('predict', array([4.775789], dtype=float32))
# ('real', 5.025438312918662)
# ('predict', array([4.762956], dtype=float32))
# ('real', 5.006233807786714)
# ('predict', array([4.749126], dtype=float32))
# ('real', 4.990403373730567)
# ('predict', array([4.733463], dtype=float32))
# ('real', 4.971627062655721)
# ('predict', array([4.721534], dtype=float32))
# ('real', 4.956143949986918)
# ('predict', array([4.707618], dtype=float32))
# ('real', 4.93778767599718)
# ('predict', array([4.695611], dtype=float32))
# ('real', 4.9226774773636)
# ('predict', array([4.6821566], dtype=float32))
# ('real', 4.90477485783615)
# ('predict', array([4.6683517], dtype=float32))
# ('real', 4.8900536008974775)
# ('predict', array([4.6577606], dtype=float32))
# ('real', 4.872628619005075)
# ('predict', array([4.6451635], dtype=float32))
# ('real', 4.861055898732684)
# ('predict', array([4.634843], dtype=float32))
# ('real', 4.847056390299658)
# ('predict', array([4.6226172], dtype=float32))
# ('real', 4.830735157671946)
# ('predict', array([4.6105895], dtype=float32))
# ('real', 4.8172422533957775)
# ('predict', array([4.601706], dtype=float32))
# ('real', 4.80093751018581)
# ('predict', array([4.5909767], dtype=float32))
# ('real', 4.788116784695244)
# ('predict', array([4.5824323], dtype=float32))
# ('real', 4.773011843554217)
# ('predict', array([4.572004], dtype=float32))
# ('real', 4.76031320251824)
# ('predict', array([4.5636992], dtype=float32))
# ('real', 4.745808449167213)
# ('predict', array([4.554884], dtype=float32))
# ('real', 4.7339745685623615)
# ('predict', array([4.547306], dtype=float32))
# ('real', 4.721970308974327)
# ('predict', array([4.538496], dtype=float32))
# ('real', 4.710642564315749)
# ('predict', array([4.5306473], dtype=float32))
# ('real', 4.697008514411277)
# ('predict', array([4.5239253], dtype=float32))
# ('real', 4.6861997555706845)
# ('predict', array([4.5161715], dtype=float32))
# ('real', 4.673235386009038)
# ('predict', array([4.508972], dtype=float32))
# ('real', 4.663187130322074)
# ('predict', array([4.5040317], dtype=float32))
# ('real', 4.652090730216637)
# ('predict', array([4.4977803], dtype=float32))
# ('real', 4.642106952424447)
# ('predict', array([4.491308], dtype=float32))
# ('real', 4.631244944791484)
# ('predict', array([4.4866753], dtype=float32))
# ('real', 4.621984253235302)
# ('predict', array([4.481751], dtype=float32))
# ('real', 4.611189665047256)
# ('predict', array([4.4782696], dtype=float32))
# ('real', 4.6030457444918405)
# ('predict', array([4.473733], dtype=float32))
# ('real', 4.592889020687064)
# ('predict', array([4.4701695], dtype=float32))
# ('real', 4.585030282449277)
# ('predict', array([4.46641], dtype=float32))
# ('real', 4.577093787853389)
# ('predict', array([2.7934253], dtype=float32))
# ('real', 4.567988243300205)
# ('predict', array([2.6178434], dtype=float32))
# ('real', 4.561141886534689)
# ('predict', array([2.6988072], dtype=float32))
# ('real', 4.552870715448003)
# ('predict', array([2.7517126], dtype=float32))
# ('real', 4.544873562732315)
# ('predict', array([2.758192], dtype=float32))
# ('real', 4.5389873464731965)
# ('predict', array([2.7657623], dtype=float32))
# ('real', 4.531620579920599)
# ('predict', array([2.7738876], dtype=float32))
# ('real', 4.525841403745601)
# ('predict', array([2.7820497], dtype=float32))
# ('real', 4.520077049782403)
# ('predict', array([2.788412], dtype=float32))
# ('real', 4.515541377735498)
# ('predict', array([2.7949853], dtype=float32))
# ('real', 4.5106557408425525)
# ('predict', array([2.8009925], dtype=float32))
# ('real', 4.505453600992614)
# ('predict', array([2.8053107], dtype=float32))
# ('real', 4.501345065737145)
# ('predict', array([2.8104331], dtype=float32))
# ('real', 4.496909843263264)
# ('predict', array([2.815431], dtype=float32))
# ('real', 4.49389993442241)
# ('predict', array([2.8222172], dtype=float32))
# ('real', 4.491273271693899)
# ('predict', array([2.829947], dtype=float32))
# ('real', 4.487381053756204)
# ('predict', array([2.8369832], dtype=float32))
# ('real', 4.484435688684381)
# ('predict', array([2.845895], dtype=float32))
# ('real', 2.7647894424302586)
# ('predict', array([2.8539848], dtype=float32))
# ('real', 2.7625032452766387)
# ('predict', array([2.864199], dtype=float32))
# ('real', 2.7589300582031377)
# ('predict', array([2.8733885], dtype=float32))
# ('real', 2.7601461194400807)
# ('predict', array([2.8849254], dtype=float32))
# ('real', 2.7614939423919163)
# ('predict', array([2.897395], dtype=float32))
# ('real', 2.7640310200593743)
# ('predict', array([2.9085095], dtype=float32))
# ('real', 2.767330125280497)
# ('predict', array([2.9228365], dtype=float32))
# ('real', 2.7704521615921043)
# ('predict', array([2.9382672], dtype=float32))
# ('real', 2.77479710874143)
# ('predict', array([2.9514656], dtype=float32))
# ('real', 2.779612705914409)
# ('predict', array([2.9671469], dtype=float32))
# ('real', 2.7837527411101965)
# ('predict', array([2.983103], dtype=float32))
# ('real', 2.7886869206816893)
# ('predict', array([2.9963207], dtype=float32))
# ('real', 2.793746918017555)
# ('predict', array([3.0089874], dtype=float32))
# ('real', 2.799654409054087)
# ('predict', array([3.0235336], dtype=float32))
# ('real', 2.8046005014849626)
# ('predict', array([3.0402298], dtype=float32))
# ('real', 2.810252267733681)
# ('predict', array([3.0546231], dtype=float32))
# ('real', 2.8168860504859765)
# ('predict', array([3.0721126], dtype=float32))
# ('real', 2.822402857742664)
# ('predict', array([3.090471], dtype=float32))
# ('real', 2.8296308320396597)
# ('predict', array([3.1061049], dtype=float32))
# ('real', 2.8356666329203444)
# ('predict', array([3.1251462], dtype=float32))
# ('real', 2.8435498720862085)
# ('predict', array([3.1417162], dtype=float32))
# ('real', 2.8518108281147776)
# ('predict', array([3.161757], dtype=float32))
# ('real', 2.8604580745216412)
# ('predict', array([3.182621], dtype=float32))
# ('real', 2.867675304221908)
# ('predict', array([3.200295], dtype=float32))
# ('real', 2.877014746149802)
# ('predict', array([3.2217312], dtype=float32))
# ('real', 2.8847750461404815)
# ('predict', array([3.2440195], dtype=float32))
# ('real', 2.8947972909836195)
# ('predict', array([3.2628376], dtype=float32))
# ('real', 2.903107153556755)
# ('predict', array([3.2859607], dtype=float32))
# ('real', 2.914019773765595)
# ('predict', array([3.3054254], dtype=float32))
# ('real', 2.92546116072238)
# ('predict', array([3.326704], dtype=float32))
# ('real', 2.9377027179969586)
# ('predict', array([3.3431833], dtype=float32))
# ('real', 2.945512384702062)
# ('predict', array([3.3589225], dtype=float32))
# ('real', 2.9592894989271374)
# ('predict', array([3.371485], dtype=float32))
# ('real', 2.9706434593190476)
# ('predict', array([3.3831255], dtype=float32))
# ('real', 2.984915879491413)
# ('predict', array([3.3919852], dtype=float32))
# ('real', 3.0007278903453938)
# ('predict', array([3.4012012], dtype=float32))
# ('real', 3.015127507673057)
# ('predict', array([3.4076173], dtype=float32))
# ('real', 3.026566512805163)
# ('predict', array([3.412539], dtype=float32))
# ('real', 3.040642521560715)
# ('predict', array([3.415842], dtype=float32))
# ('real', 3.051978551621711)
# ('predict', array([3.4175882], dtype=float32))
# ('real', 3.0635895857022373)
# ('predict', array([3.4178042], dtype=float32))
# ('real', 3.0784273088646983)
# ('predict', array([3.4165192], dtype=float32))
# ('real', 3.0936060643556362)
# ('predict', array([3.4140365], dtype=float32))
# ('real', 3.1091177468553712)
# ('predict', array([3.4091322], dtype=float32))
# ('real', 3.1250540474928257)
# ('predict', array([3.401835], dtype=float32))
# ('real', 3.1413160245138507)
# ('predict', array([3.3919227], dtype=float32))
# ('real', 3.161290999654774)
# ('predict', array([3.3816566], dtype=float32))
# ('real', 3.1783064923274953)
# ('predict', array([3.36691], dtype=float32))
# ('real', 3.1956866010920715)
# ('predict', array([3.3525226], dtype=float32))
# ('real', 3.2169725292576214)
# ('predict', array([3.3332615], dtype=float32))
# ('real', 3.2350761659763996)
# ('predict', array([3.3116946], dtype=float32))
# ('real', 3.2535136762402375)
# ('predict', array([3.2924788], dtype=float32))
# ('real', 3.2684876660371533)
# ('predict', array([3.2726548], dtype=float32))
# ('real', 3.287390344001634)
# ('predict', array([3.2516928], dtype=float32))
# ('real', 3.3026775698228037)
# ('predict', array([3.2254593], dtype=float32))
# ('real', 3.318231237579054)
# ('predict', array([3.198268], dtype=float32))
# ('real', 3.338873965315815)
# ('predict', array([3.17064], dtype=float32))
# ('real', 3.356646682768441)
# ('predict', array([3.142315], dtype=float32))
# ('real', 3.3671747686075864)
# ('predict', array([3.1181126], dtype=float32))
# ('real', 3.3784993958364518)
# ('predict', array([3.09135], dtype=float32))
# ('real', 3.3908499992976315)
# ('predict', array([3.0605402], dtype=float32))
# ('real', 3.4022048712951842)
# ('predict', array([3.034091], dtype=float32))
# ('real', 3.4145046901985316)
# ('predict', array([3.0020652], dtype=float32))
# ('real', 3.425336986962107)
# ('predict', array([2.9743004], dtype=float32))
# ('real', 3.43704556298018)
# ('predict', array([2.9406927], dtype=float32))
# ('real', 3.4453418755737744)
# ('predict', array([2.905885], dtype=float32))
# ('real', 3.4523508179656206)
# ('predict', array([2.8704958], dtype=float32))
# ('real', 3.4559081787796546)
# ('predict', array([2.8345745], dtype=float32))
# ('real', 3.457162472560562)
# ('predict', array([2.8041744], dtype=float32))
# ('real', 3.456159407002421)
# ('predict', array([2.76771], dtype=float32))
# ('real', 3.4538086748209706)
# ('predict', array([2.7333424], dtype=float32))
# ('real', 3.449613604546075)
# ('predict', array([2.695361], dtype=float32))
# ('real', 3.444381392602856)
# ('predict', array([2.6634877], dtype=float32))
# ('real', 3.4362906767449393)
# ('predict', array([2.6291435], dtype=float32))
# ('real', 3.428307766247754)
# ('predict', array([2.591235], dtype=float32))
# ('real', 3.4189958613603517)
# ('predict', array([2.5532053], dtype=float32))
# ('real', 3.4056242580321667)
# ('predict', array([2.521765], dtype=float32))
# ('real', 3.392958346623256)
# ('predict', array([2.4845421], dtype=float32))
# ('real', 3.3753554963923267)
# ('predict', array([2.4470274], dtype=float32))
# ('real', 3.358776784381277)
# ('predict', array([2.4161525], dtype=float32))
# ('real', 3.336640233158699)
# ('predict', array([2.3809803], dtype=float32))
# ('real', 3.3163158512303066)
# ('predict', array([2.34591], dtype=float32))
# ('real', 3.2900888038682643)
# ('predict', array([2.3173084], dtype=float32))
# ('real', 3.26296499756854)
# ('predict', array([2.2875378], dtype=float32))
# ('real', 3.2397418338331425)
# ('predict', array([2.256119], dtype=float32))
# ('real', 3.2137600141223777)
# ('predict', array([2.2306378], dtype=float32))
# ('real', 3.1842866315035456)
# ('predict', array([2.2021706], dtype=float32))
# ('real', 3.159009567940376)
# ('predict', array([2.1767855], dtype=float32))
# ('real', 3.1277889565732937)
# ('predict', array([2.1548164], dtype=float32))
# ('real', 3.09561660539674)
# ('predict', array([2.1298757], dtype=float32))
# ('real', 3.068024998217595)
# ('predict', array([2.105394], dtype=float32))
# ('real', 3.03390913055896)
# ('predict', array([2.0855582], dtype=float32))
# ('real', 2.9987794135169232)
# ('predict', array([2.0629704], dtype=float32))
# ('real', 2.968705909779417)
# ('predict', array([2.040676], dtype=float32))
# ('real', 2.931643846110049)
# ('predict', array([2.022314], dtype=float32))
# ('real', 2.900078825533597)
# ('predict', array([2.001287], dtype=float32))
# ('real', 2.86784745636123)
# ('predict', array([1.980423], dtype=float32))
# ('real', 2.8283836840332284)
# ('predict', array([1.960066], dtype=float32))
# ('real', 2.7949462145977626)
# ('predict', array([1.9432601], dtype=float32))
# ('real', 2.760979977844545)
# ('predict', array([1.9240265], dtype=float32))
# ('real', 2.7262743379767334)
# ('predict', array([1.9049932], dtype=float32))
# ('real', 2.691172200057426)
# ('predict', array([1.8893291], dtype=float32))
# ('real', 2.6487417179967667)
# ('predict', array([1.8715123], dtype=float32))
# ('real', 2.605913579282773)
# ('predict', array([1.853933], dtype=float32))
# ('real', 2.569931641382378)
# ('predict', array([1.8369142], dtype=float32))
# ('real', 2.5269020072640718)
# ('predict', array([1.822974], dtype=float32))
# ('real', 2.490927494107812)
# ('predict', array([1.8072559], dtype=float32))
# ('real', 2.4546582142073063)
# ('predict', array([1.7919083], dtype=float32))
# ('real', 2.411245173412769)
# ('predict', array([1.7772107], dtype=float32))
# ('real', 2.3754988779314923)
# ('predict', array([1.7631671], dtype=float32))
# ('real', 2.3407199897716833)
# ('predict', array([1.7497965], dtype=float32))
# ('real', 2.2989367843249995)
# ('predict', array([1.7352284], dtype=float32))
# ('real', 2.264814161302766)
# ('predict', array([1.7231807], dtype=float32))
# ('real', 2.2248098697274417)
# ('predict', array([1.7104288], dtype=float32))
# ('real', 2.1925180528447847)
# ('predict', array([1.7000053], dtype=float32))
# ('real', 2.1552826066235897)
# ('predict', array([1.6905502], dtype=float32))
# ('real', 2.1253907051969865)
# ('predict', array([1.6806465], dtype=float32))
# ('real', 2.0908643594609964)
# ('predict', array([1.6717216], dtype=float32))
# ('real', 2.0632287572954007)
# ('predict', array([1.6648784], dtype=float32))
# ('real', 2.031152928324021)
# ('predict', array([1.6585444], dtype=float32))
# ('real', 2.0053390605292574)
# ('predict', array([1.6528603], dtype=float32))
# ('real', 1.9777426509184617)
# ('predict', array([1.6488985], dtype=float32))
# ('real', 1.953157914863926)
# ('predict', array([1.6455344], dtype=float32))
# ('real', 1.9266169598536296)
# ('predict', array([7.7962594], dtype=float32))
# ('real', 1.9029833959280695)
# ('predict', array([8.667221], dtype=float32))
# ('real', 1.8751346043038237)
# ('predict', array([8.25937], dtype=float32))
# ('real', 1.8523801690535857)
# ('predict', array([7.803598], dtype=float32))
# ('real', 1.8298163739506539)
# ('predict', array([7.823867], dtype=float32))
# ('real', 1.807621226389469)
# ('predict', array([7.839345], dtype=float32))
# ('real', 1.781417008469936)
# ('predict', array([7.8559694], dtype=float32))
# ('real', 1.7579025216698276)
# ('predict', array([7.876195], dtype=float32))
# ('real', 1.7326345906065403)
# ('predict', array([7.896493], dtype=float32))
# ('real', 1.7119523391422853)
# ('predict', array([7.910406], dtype=float32))
# ('real', 1.691579655029986)
# ('predict', array([7.9218416], dtype=float32))
# ('real', 1.6676761591032925)
# ('predict', array([7.9304285], dtype=float32))
# ('real', 1.648296822869764)
# ('predict', array([7.934726], dtype=float32))
# ('real', 1.6292678962188443)
# ('predict', array([7.933421], dtype=float32))
# ('real', 1.6091045214123798)
# ('predict', array([7.925463], dtype=float32))
# ('real', 1.5911288631895522)
# ('predict', array([7.910906], dtype=float32))
# ('real', 1.5720871739011115)
# ('predict', array([7.8992796], dtype=float32))
# ('real', 1.5551703737533042)
# ('predict', array([7.8902473], dtype=float32))
# ('real', 1.5388272332569486)
# ('predict', array([7.8838687], dtype=float32))
# ('real', 1.5199892998739488)
# ('predict', array([7.8782916], dtype=float32))
# ('real', 1.5050306698568259)
# ('predict', array([7.8724246], dtype=float32))
# ('real', 1.4893658787487098)
# ('predict', array([7.867512], dtype=float32))
# ('real', 1.4757114332553638)
# ('predict', array([7.8634534], dtype=float32))
# ('real', 1.4602669998351616)
# ('predict', array([7.859239], dtype=float32))
# ('real', 1.4482367262467077)
# ('predict', array([7.8557005], dtype=float32))
# ('real', 1.4369407347717311)
# ('predict', array([7.852744], dtype=float32))
# ('real', 1.426407604339136)
# ('predict', array([7.849666], dtype=float32))
# ('real', 1.4166833073589313)
# ('predict', array([7.846689], dtype=float32))
# ('real', 1.4077832584379573)
# ('predict', array([7.844498], dtype=float32))
# ('real', 1.399730516278011)
# ('predict', array([7.843044], dtype=float32))
# ('real', 1.3933192224976165)
# ('predict', array([7.841056], dtype=float32))
# ('real', 1.3863098781434409)
# ('predict', array([7.8390727], dtype=float32))
# ('real', 1.3808568287745153)
# ('predict', array([7.8373394], dtype=float32))
# ('real', 1.3762967597814386)
# ('predict', array([7.8363976], dtype=float32))
# ('real', 1.3720349590463117)
# Цель достигнута

# %%
type(testY)
# Out:
# torch.autograd.variable.Variable
