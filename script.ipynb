# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

# %%
training_set = pd.read_csv('data.csv')
training_set = training_set.iloc[:,1:2].values
plt.plot(training_set, label = ' ')
plt.show()

# %%
def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

sc = MinMaxScaler()
training_data = sc.fit_transform(training_set)
seq_length = 4
x, y = sliding_windows(training_data, seq_length)

train_size = int(len(y) * 0.5)
test_size = len(y) - train_size

dataX = Variable(torch.Tensor(np.array(x)))
dataY = Variable(torch.Tensor(np.array(y)))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])))

testX = Variable(torch.Tensor(np.array(x[train_size:len(x)])))
testY = Variable(torch.Tensor(np.array(y[train_size:len(y)])))

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %%
num_epochs = 4000
learning_rate = 0.01

input_size = 1
hidden_size = 2
num_layers = 1

num_classes = 1

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    
    # obtain the loss function
    loss = criterion(outputs, trainY)
    
    loss.backward()
    
    optimizer.step()

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)

plt.axvline(x=train_size, c='r', linestyle='--')

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('Time-Series Prediction')
plt.show()

# %%
import time
import sys
import numpy as np
import vrep
from assets import *

# %%
class Algorithm:
  def __init__(self, ROBOT, TARGET):
    self.state = States.MOVING

    self.MIN_DETECTION_DIST = 0
    self.MAX_DETECTION_DIST = 1

    self.ROBOT = ROBOT
    self.TARGET = TARGET
    self.SPEED = 1.5
    self.INDENT_DIST = 0.5
    self.ar = []
    self.SLEEP_TIME = 0.2
    self.PI = math.pi
    self.bot_dir = None
    self.bot_pos = None
    self.bot_euler_angles = None

    self.target_pos = None
    self.target_dir = np.zeros(3)

    self.detect = np.zeros(16)

    self._init_client_id()
    self._init_robot_handle()
    self._init_sensor_handles()
    self._init_wheels_handles()
    self._init_target_handle()

    self.obstacle_dist_stab_PID = PIDController(50)
    self.obstacle_follower_PID = PIDController(50)
    self.obstacle_dist_stab_PID.set_coefficients(2, 0, 0.5)
    self.obstacle_follower_PID.set_coefficients(2, 0, 0)

    self.min_dist_to_target = None

    self.print_info()


  def _init_client_id(self):
    vrep.simxFinish(-1)

    self.client_id = vrep.simxStart('127.0.0.1', 19999, True, True, 5000, 5)

    if self.client_id != -1:
      print('')
    else:
      sys.exit('')


  def _init_robot_handle(self):
    error_code, self.bot_handle = vrep.simxGetObjectHandle(self.client_id, self.ROBOT, vrep.simx_opmode_oneshot_wait)


  def _init_sensor_handles(self):
    self.sensor_handles = []

    for x in range(0, 16):
      error_code, sensor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_ultrasonicSensor' + str(x + 1), vrep.simx_opmode_oneshot_wait)
      self.sensor_handles.append(sensor_handle)
      vrep.simxReadProximitySensor(self.client_id, sensor_handle, vrep.simx_opmode_streaming)


  def _init_wheels_handles(self):
    error_code, self.left_motor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_leftMotor', vrep.simx_opmode_oneshot_wait)
    error_code, self.right_motor_handle = vrep.simxGetObjectHandle(self.client_id, 'Pioneer_p3dx_rightMotor', vrep.simx_opmode_oneshot_wait)


  def _init_target_handle(self):
    error_code, self.target_handle = vrep.simxGetObjectHandle(self.client_id, self.TARGET, vrep.simx_opmode_oneshot_wait)


  def _init_values(self):
    # Инициализация значений цели и робота
    error_code, _ = vrep.simxGetObjectPosition(self.client_id, self.target_handle, -1, vrep.simx_opmode_oneshot)
    error_code, _ = vrep.simxGetObjectPosition(self.client_id, self.bot_handle, -1, vrep.simx_opmode_oneshot)
    error_code, _ = vrep.simxGetObjectOrientation(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)


  def read_values(self):
    # Чтение значений позиции цели
    error_code, target_pos = vrep.simxGetObjectPosition(self.client_id, self.target_handle, -1, vrep.simx_opmode_streaming)
    self.target_pos = Vector3(x=target_pos[0], y=target_pos[1], z=0)

    # Чтение значений позиции робота
    error_code, bot_pos = vrep.simxGetObjectPosition(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)
    self.bot_pos = Vector3(x=bot_pos[0], y=bot_pos[1], z=0)

    # Чтение значений углов Эйлера робота
    error_code, bot_euler_angles = vrep.simxGetObjectOrientation(self.client_id, self.bot_handle, -1, vrep.simx_opmode_streaming)
    self.bot_euler_angles = Vector3(x=0, y=0, z=bot_euler_angles[2])


  def stop_move(self):
    # Остановка движения робота
    error_code = vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  0, vrep.simx_opmode_streaming)
    error_code = vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, 0, vrep.simx_opmode_streaming)


  def read_from_sensors(self):
    # Чтение значений с сенсоров
    for i in range(0, 16):
      error_code, detection_state, detected_point, detected_object_handle, detected_surface_normal_vector = vrep.simxReadProximitySensor(self.client_id, self.sensor_handles[i], vrep.simx_opmode_streaming)

      # Значение дистанции до препятствия
      dist = math.sqrt(detected_point[0] ** 2 + detected_point[1] ** 2 + detected_point[2] ** 2)

      # Присвоение значений датчиков: чем больше значение, тем ближе к конкретному датчику препятствие
      if dist < self.MIN_DETECTION_DIST:
        self.detect[i] = self.MIN_DETECTION_DIST
      elif dist > self.MAX_DETECTION_DIST or detection_state == False:
        self.detect[i] = self.MAX_DETECTION_DIST
      else:
        self.detect[i] = self.MAX_DETECTION_DIST - ((dist - self.MAX_DETECTION_DIST) / (self.MIN_DETECTION_DIST - self.MAX_DETECTION_DIST))


  def print_info(self):
    print('Цель: ' + self.TARGET)
    print('Робот: ' + self.ROBOT)
    print('Скорость: ' + str(self.SPEED))


  def tick(self):
    # Задержка программы
    time.sleep(self.SLEEP_TIME)


  def loop(self):
    self._init_values()
    self.read_values()
    i = 0
    # Основной цикл программы
    while Utils.distance_between_points(self.bot_pos, self.target_pos) > 0.4 or Utils.distance_between_points(self.bot_pos, self.target_pos) == 0:
      self.tick()
      # print(Utils.distance_between_points(self.bot_pos, self.target_pos))
      i = i+1
      # Останавливаем движение и читаем данные робота и цели
      self.stop_move()
      self.read_values()

      # Получаем данные с сенсоров
      self.read_from_sensors()

      # Инициализируем новый кватернион
      q_rot = Quaternion()
      # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
      q_rot.set_from_vector(self.bot_euler_angles.z, Vector3(0, 0, 1))
      # Присваиваем вектору робота значения поворота вектора кватернионом
      self.bot_dir = q_rot.rotate(Vector3(1, 0, 0))

      # Проверка текущего состояния и выполнение соответствующей функции
      if self.state == States.MOVING:
        self.action_moving()
      elif self.state == States.ROTATING:
        self.action_rotating()
      elif self.state == States.ROUNDING:
        self.action_rounding()

    print('Цель достигнута')
    self.stop_move()


  def action_moving(self):
    # Если робот оказалася близко к препятствию, объезжаем это препятствие, иначе продолжаем движение до цели
    if (self.detect[4] + self.detect[5])/2 < self.INDENT_DIST:
      # Инициализируем новый кватернион
      q = Quaternion()
      # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
      q.set_from_vector(self.PI/2, Vector3(0, 0, 1))
      # Присваиваем вектору цели значения поворота вектора направления робота кватернионом
      self.target_dir = q.rotate(self.bot_dir)
      # Переключаем состояние
      self.state = States.ROTATING
    else:
      # Значение угла в радианах между векторами направления движения робота и между роботом и целью
      angle = Utils.angle_between_vectors(self.bot_dir, self.target_pos.minus(self.bot_pos))

      # Корректируем движение робота до прямолинейного до цели, если необходимо
      if math.fabs(angle) > self.PI/180:
        vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  self.SPEED + angle, vrep.simx_opmode_streaming)
        vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED - angle, vrep.simx_opmode_streaming)
      else:
        vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle,  self.SPEED, vrep.simx_opmode_streaming)
        vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED, vrep.simx_opmode_streaming)


  def action_rotating(self):
    # Значение угла в радианах между векторами направления движения робота и цели
    angle = Utils.angle_between_vectors(self.bot_dir, self.target_dir)

    # Поворачиваем робота вокруг своей оси, если необходимо, иначе переключаем состояние
    if math.fabs(angle) > 5 * self.PI/180:
      vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle, angle, vrep.simx_opmode_streaming)
      vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, -angle, vrep.simx_opmode_streaming)
    else:
      self.state = States.ROUNDING


  def action_rounding(self):
    # Инициализация нового кватерниона
    q = Quaternion()
    # Получаем кватернион из угла разворота вокруг вектора и самого вектора соответственно
    q.set_from_vector(self.PI/2, Vector3(0, 0, 1))
    # Присваиваем перпендикуляру вектора робота значения поворота вектора направления робота кватернионом
    perp_bot_dir = q.rotate(self.bot_dir)

    # Значение угла в радианах между векторами перпендикуляра к роботу и между роботом и целью
    angle = Utils.angle_between_vectors(perp_bot_dir, self.target_pos.minus(self.bot_pos))
    #==============================================================================
    f1 = open('f1.txt', 'a')
    z = str(angle)
    f1.write(z+'\n')
    self.ar.append(angle)
    #print(len(self.ar))
    # Текущая дистанция до цели
    current_dist_to_target1 = Utils.distance_between_points(self.bot_pos, self.target_pos)
    current_dist_to_target = data_predict[len(self.ar)]
    print('predict',current_dist_to_target)
    print('real', current_dist_to_target1)
    #==============================================================================
    f2 = open('f2.txt', 'a')
    m = str(current_dist_to_target)
    f2.write(m+'\n')

    # Если минимальное значение дистанции до цели меньше, чем текущее, то присваиваем минимальному значению текущее
    if self.min_dist_to_target == None or self.min_dist_to_target <= current_dist_to_target:
      self.min_dist_to_target = current_dist_to_target
    # Прекращаем объезд препятствия
    elif math.fabs(angle) < 5.0 / 180 * self.PI:
      self.state = States.MOVING
      return

    # Разница между значениями двух крайних справа датчиков
    delta = self.detect[7] - self.detect[8]

    # Устанавливаем расстояние до препятствия
    obstacle_dist = min([self.detect[7], self.detect[8]]) - self.INDENT_DIST

    obstacle_dist_stab = self.obstacle_dist_stab_PID.output(obstacle_dist)
    obstacle_follower = self.obstacle_follower_PID.output(delta)
  
    vrep.simxSetJointTargetVelocity(self.client_id, self.left_motor_handle, self.SPEED + obstacle_follower + obstacle_dist_stab - (1 - (self.detect[4] + self.detect[5])/2), vrep.simx_opmode_streaming)
    vrep.simxSetJointTargetVelocity(self.client_id, self.right_motor_handle, self.SPEED - obstacle_follower - obstacle_dist_stab + (1 - (self.detect[4] + self.detect[5])/2), vrep.simx_opmode_streaming)


bug = Algorithm(ROBOT='P3DX', TARGET='Destination')

bug.loop()
# Out:
# Цель: Destination
# Робот: P3DX
# Скорость: 1.5
# ('predict', array([7.8232365], dtype=float32))
# ('real', 7.881274065215608)
# ('predict', array([7.841836], dtype=float32))
# ('real', 7.881740069866852)
# ('predict', array([7.861999], dtype=float32))
# ('real', 7.893409313819327)
# ('predict', array([7.880374], dtype=float32))
# ('real', 7.918259426921946)
# ('predict', array([7.893262], dtype=float32))
# ('real', 7.932876290553588)
# ('predict', array([7.9068885], dtype=float32))
# ('real', 7.9380942882448)
# ('predict', array([7.9156604], dtype=float32))
# ('real', 7.930236992950097)
# ('predict', array([7.920398], dtype=float32))
# ('real', 7.912954605993055)
# ('predict', array([7.9200916], dtype=float32))
# ('real', 7.890270951349736)
# ('predict', array([7.9131675], dtype=float32))
# ('real', 7.877056086787368)
# ('predict', array([7.9003115], dtype=float32))
# ('real', 7.867034211116444)
# ('predict', array([7.8925066], dtype=float32))
# ('real', 7.8598796037792455)
# ('predict', array([7.882779], dtype=float32))
# ('real', 7.852266628270516)
# ('predict', array([7.87627], dtype=float32))
# ('real', 7.846475589741158)
# ('predict', array([7.870018], dtype=float32))
# ('real', 7.841386196814222)
# ('predict', array([7.863556], dtype=float32))
# ('real', 7.83557659185375)
# ('predict', array([7.859028], dtype=float32))
# ('real', 7.830350754376318)
# ('predict', array([7.8545823], dtype=float32))
# ('real', 7.8261361646261)
# ('predict', array([7.849948], dtype=float32))
# ('real', 7.821991782110434)
# ('predict', array([7.8466887], dtype=float32))
# ('real', 7.817996808100707)
# ('predict', array([7.8434544], dtype=float32))
# ('real', 7.814762821205305)
# ('predict', array([7.8400874], dtype=float32))
# ('real', 7.811460055878492)
# ('predict', array([7.8372293], dtype=float32))
# ('real', 7.808167642422578)
# ('predict', array([7.835101], dtype=float32))
# ('real', 7.807051003208541)
# ('predict', array([7.8334365], dtype=float32))
# ('real', 7.806064884792487)
# ('predict', array([7.83102], dtype=float32))
# ('real', 7.805035230269958)
# ('predict', array([7.829297], dtype=float32))
# ('real', 7.804213903832324)
# ('predict', array([7.8275547], dtype=float32))
# ('real', 7.8035719857844565)
# ('predict', array([7.8266506], dtype=float32))
# ('real', 7.803281115547505)
# ('predict', array([7.8252287], dtype=float32))
# ('real', 7.803415412363529)
# ('predict', array([7.824201], dtype=float32))
# ('real', 7.803996030573529)
# ('predict', array([7.82405], dtype=float32))
# ('real', 7.8048463997494455)
# ('predict', array([7.8233733], dtype=float32))
# ('real', 7.806261497825471)
# ('predict', array([7.823532], dtype=float32))
# ('real', 7.8078271173919545)
# ('predict', array([7.8231955], dtype=float32))
# ('real', 7.810236664162385)
# ('predict', array([7.82379], dtype=float32))
# ('real', 7.81346342825211)
# ('predict', array([7.8240523], dtype=float32))
# ('real', 7.8169226914608485)
# ('predict', array([7.8249893], dtype=float32))
# ('real', 7.822520625522186)
# ('predict', array([7.8257923], dtype=float32))
# ('real', 7.829228958232297)
# ('predict', array([7.8272233], dtype=float32))
# ('real', 7.836298238804054)
# ('predict', array([7.8284225], dtype=float32))
# ('real', 7.842027527321514)
# ('predict', array([7.83018], dtype=float32))
# ('real', 7.846995822370864)
# ('predict', array([7.8317795], dtype=float32))
# ('real', 7.851578508212797)
# ('predict', array([7.8342314], dtype=float32))
# ('real', 7.856436521798083)
# ('predict', array([7.8367357], dtype=float32))
# ('real', 7.862665844814675)
# ('predict', array([7.8399487], dtype=float32))
# ('real', 7.8694192968876635)
# ('predict', array([7.842341], dtype=float32))
# ('real', 7.8757882636965695)
# ('predict', array([7.845629], dtype=float32))
# ('real', 7.883547498052732)
# ('predict', array([7.8486867], dtype=float32))
# ('real', 7.891782618943102)
# ('predict', array([7.851403], dtype=float32))
# ('real', 7.899563414160439)
# ('predict', array([7.854393], dtype=float32))
# ('real', 7.908615686852091)
# ('predict', array([7.858079], dtype=float32))
# ('real', 7.9182476758143)
# ('predict', array([7.861047], dtype=float32))
# ('real', 7.925639729897688)
# ('predict', array([7.865242], dtype=float32))
# ('real', 7.928528669513002)
# ('predict', array([7.869382], dtype=float32))
# ('real', 7.926360064055749)
# ('predict', array([7.8739524], dtype=float32))
# ('real', 7.917008119645557)
# ('predict', array([7.8779073], dtype=float32))
# ('real', 7.9018529596614)
# ('predict', array([7.883246], dtype=float32))
# ('real', 7.883645326778887)
# ('predict', array([7.888487], dtype=float32))
# ('real', 7.864116626903389)
# ('predict', array([7.8931427], dtype=float32))
# ('real', 7.846719553791301)
# ('predict', array([7.899363], dtype=float32))
# ('real', 7.826392903628143)
# ('predict', array([7.905734], dtype=float32))
# ('real', 7.800309945622896)
# ('predict', array([7.9110107], dtype=float32))
# ('real', 7.7674851152094595)
# ('predict', array([7.9172025], dtype=float32))
# ('real', 7.726782024402486)
# ('predict', array([7.923306], dtype=float32))
# ('real', 7.681164243754005)
# ('predict', array([7.9308033], dtype=float32))
# ('real', 7.638296209535502)
# ('predict', array([7.9317408], dtype=float32))
# ('real', 7.595279124372245)
# ('predict', array([7.9275417], dtype=float32))
# ('real', 7.558854121108079)
# ('predict', array([7.920649], dtype=float32))
# ('real', 7.511647918040149)
# ('predict', array([7.9126663], dtype=float32))
# ('real', 7.458924268198886)
# ('predict', array([7.903721], dtype=float32))
# ('real', 7.404534563777936)
# ('predict', array([7.895736], dtype=float32))
# ('real', 7.348054900685883)
# ('predict', array([7.884335], dtype=float32))
# ('real', 7.293005759988112)
# ('predict', array([7.8709955], dtype=float32))
# ('real', 7.236593178402647)
# ('predict', array([7.8546367], dtype=float32))
# ('real', 7.179552713752772)
# ('predict', array([7.8355365], dtype=float32))
# ('real', 7.122374551403342)
# ('predict', array([7.8137364], dtype=float32))
# ('real', 7.065105168366253)
# ('predict', array([7.794082], dtype=float32))
# ('real', 7.007466157407786)
# ('predict', array([7.7714295], dtype=float32))
# ('real', 6.950022985903044)
# ('predict', array([7.7430553], dtype=float32))
# ('real', 6.900675898412084)
# ('predict', array([7.7197475], dtype=float32))
# ('real', 6.8520837917083455)
# ('predict', array([7.690404], dtype=float32))
# ('real', 6.79797513838474)
# ('predict', array([7.657735], dtype=float32))
# ('real', 6.746009136370253)
# ('predict', array([7.630711], dtype=float32))
# ('real', 6.702398295686361)
# ('predict', array([7.5930676], dtype=float32))
# ('real', 6.660608088841849)
# ('predict', array([7.556738], dtype=float32))
# ('real', 6.615435018446807)
# ('predict', array([7.5172653], dtype=float32))
# ('real', 6.588744243491116)
# ('predict', array([7.484673], dtype=float32))
# ('real', 6.5784638908934845)
# ('predict', array([7.4402685], dtype=float32))
# ('real', 6.54880858701046)
# ('predict', array([7.399411], dtype=float32))
# ('real', 6.507837049481888)
# ('predict', array([7.3649163], dtype=float32))
# ('real', 6.483108230856358)
# ('predict', array([7.319138], dtype=float32))
# ('real', 6.46071309238048)
# ('predict', array([7.2774196], dtype=float32))
# ('real', 6.447151333095397)
# ('predict', array([7.233518], dtype=float32))
# ('real', 6.425982650747239)
# ('predict', array([7.198754], dtype=float32))
# ('real', 6.405510955969077)
# ('predict', array([7.151769], dtype=float32))
# ('real', 6.389821685890069)
# ('predict', array([7.1187606], dtype=float32))
# ('real', 6.3800725039994814)
# ('predict', array([7.07107], dtype=float32))
# ('real', 6.373891826858936)
# ('predict', array([7.038454], dtype=float32))
# ('real', 6.368508853583714)
# ('predict', array([7.0185504], dtype=float32))
# ('real', 5.783503684109671)
# ('predict', array([6.984892], dtype=float32))
# ('real', 5.776890292467624)
# ('predict', array([6.9487543], dtype=float32))
# ('real', 5.769683972131877)
# ('predict', array([6.9042344], dtype=float32))
# ('real', 5.766524268172382)
# ('predict', array([6.8717856], dtype=float32))
# ('real', 5.77553759579697)
# ('predict', array([6.82531], dtype=float32))
# ('real', 5.79922817646077)
# ('predict', array([6.7862134], dtype=float32))
# ('real', 5.813711362704674)
# ('predict', array([6.754466], dtype=float32))
# ('real', 5.828747407387375)
# ('predict', array([6.7123117], dtype=float32))
# ('real', 5.85748534928784)
# ('predict', array([6.6857023], dtype=float32))
# ('real', 5.881804617199999)
# ('predict', array([6.6454515], dtype=float32))
# ('real', 5.894213272841374)
# ('predict', array([6.6211066], dtype=float32))
# ('real', 5.909699388858549)
# ('predict', array([6.583783], dtype=float32))
# ('real', 5.926667275337984)
# ('predict', array([6.554684], dtype=float32))
# ('real', 5.93882974716049)
# ('predict', array([6.531669], dtype=float32))
# ('real', 5.9451702056384494)
# ('predict', array([6.5076237], dtype=float32))
# ('real', 5.95432685022367)
# ('predict', array([6.48076], dtype=float32))
# ('real', 5.967544739277524)
# ('predict', array([6.4638715], dtype=float32))
# ('real', 5.9829786419538395)
# ('predict', array([6.4391346], dtype=float32))
# ('real', 6.000796073477492)
# ('predict', array([6.421606], dtype=float32))
# ('real', 6.017631312199319)
# ('predict', array([6.4044104], dtype=float32))
# ('real', 6.0249620806029975)
# ('predict', array([6.39381], dtype=float32))
# ('real', 6.0298504011892105)
# ('predict', array([6.3800654], dtype=float32))
# ('real', 6.039269042478439)
# ('predict', array([6.3741455], dtype=float32))
# ('real', 6.0534377756835696)
# ('predict', array([6.364874], dtype=float32))
# ('real', 6.070063880932948)
# ('predict', array([6.3615246], dtype=float32))
# ('real', 6.074762562917913)
# ('predict', array([6.356257], dtype=float32))
# ('real', 6.079392427823309)
# ('predict', array([5.596279], dtype=float32))
# ('real', 6.083846387042999)
# ('predict', array([5.9610653], dtype=float32))
# ('real', 6.092756253792077)
# ('predict', array([5.7465615], dtype=float32))
# ('real', 6.110868552545785)
# ('predict', array([5.8480816], dtype=float32))
# ('real', 6.12930493471505)
# ('predict', array([5.853699], dtype=float32))
# ('real', 6.145339531084313)
# ('predict', array([5.8665414], dtype=float32))
# ('real', 6.16099851969082)
# ('predict', array([5.8798842], dtype=float32))
# ('real', 6.178435399912852)
# ('predict', array([5.893882], dtype=float32))
# ('real', 6.194436687765194)
# ('predict', array([5.9079165], dtype=float32))
# ('real', 6.213447748335511)
# ('predict', array([5.918191], dtype=float32))
# ('real', 6.233066595200562)
# ('predict', array([5.931028], dtype=float32))
# ('real', 6.253247697632706)
# ('predict', array([5.9428296], dtype=float32))
# ('real', 6.271381211062766)
# ('predict', array([5.95105], dtype=float32))
# ('real', 6.292664512975283)
# ('predict', array([5.963169], dtype=float32))
# ('real', 6.3117683460142695)
# ('predict', array([5.972329], dtype=float32))
# ('real', 6.334116479533801)
# ('predict', array([5.9824185], dtype=float32))
# ('real', 6.356923822190867)
# ('predict', array([5.9895926], dtype=float32))
# ('real', 6.380101893086059)
# ('predict', array([6.000798], dtype=float32))
# ('real', 6.400608641803673)
# ('predict', array([6.0104637], dtype=float32))
# ('real', 6.424217772493546)
# ('predict', array([6.021733], dtype=float32))
# ('real', 6.445154031262087)
# ('predict', array([6.0302896], dtype=float32))
# ('real', 6.469801688888535)
# ('predict', array([6.0438366], dtype=float32))
# ('real', 6.492254326054346)
# ('predict', array([6.0555468], dtype=float32))
# ('real', 6.523283710613426)
# ('predict', array([6.0654945], dtype=float32))
# ('real', 6.548512252220442)
# ('predict', array([6.080157], dtype=float32))
# ('real', 6.577512103827422)
# ('predict', array([6.0890865], dtype=float32))
# ('real', 6.60575561617863)
# ('predict', array([6.1043673], dtype=float32))
# ('real', 6.632405054811662)
# ('predict', array([6.1165805], dtype=float32))
# ('real', 6.657491859966822)
# ('predict', array([6.1284733], dtype=float32))
# ('real', 6.683779654273533)
# ('predict', array([6.138999], dtype=float32))
# ('real', 6.711029290731129)
# ('predict', array([6.1534147], dtype=float32))
# ('real', 6.7353768683273305)
# ('predict', array([6.166003], dtype=float32))
# ('real', 6.763730276493975)
# ('predict', array([6.1765084], dtype=float32))
# ('real', 6.792588385728405)
# ('predict', array([6.1920676], dtype=float32))
# ('real', 6.818219036764837)
# ('predict', array([6.205305], dtype=float32))
# ('real', 6.84421560641218)
# ('predict', array([6.2166357], dtype=float32))
# ('real', 6.872425238712127)
# ('predict', array([6.2331595], dtype=float32))
# ('real', 6.8989074639188654)
# ('predict', array([6.2434993], dtype=float32))
# ('real', 6.931552019855154)
# ('predict', array([6.261158], dtype=float32))
# ('real', 6.952785673882464)
# ('predict', array([6.2757397], dtype=float32))
# ('real', 6.967232529687449)
# ('predict', array([6.288051], dtype=float32))
# ('real', 6.9812368485687655)
# ('predict', array([6.3059254], dtype=float32))
# ('real', 6.993890923188134)
# ('predict', array([6.321068], dtype=float32))
# ('real', 7.004621406993413)
# ('predict', array([6.333761], dtype=float32))
# ('real', 7.012755533057876)
# ('predict', array([6.352229], dtype=float32))
# ('real', 7.016460768570058)
# ('predict', array([6.367844], dtype=float32))
# ('real', 7.015289161461706)
# ('predict', array([6.381037], dtype=float32))
# ('real', 7.00880858155039)
# ('predict', array([6.391654], dtype=float32))
# ('real', 7.006039122597434)
# ('predict', array([6.411831], dtype=float32))
# ('real', 6.9932272634019945)
# ('predict', array([6.42758], dtype=float32))
# ('real', 6.975955413022833)
# ('predict', array([6.441962], dtype=float32))
# ('real', 6.95698087572245)
# ('predict', array([6.457795], dtype=float32))
# ('real', 6.941917342389764)
# ('predict', array([6.4777083], dtype=float32))
# ('real', 6.922166295854966)
# ('predict', array([6.497054], dtype=float32))
# ('real', 6.8959526870312855)
# ('predict', array([6.5129843], dtype=float32))
# ('real', 6.873009950725356)
# ('predict', array([6.5357256], dtype=float32))
# ('real', 6.836901483383614)
# ('predict', array([6.55486], dtype=float32))
# ('real', 6.799545641135933)
# ('predict', array([6.570521], dtype=float32))
# ('real', 6.76566276137909)
# ('predict', array([6.5921807], dtype=float32))
# ('real', 6.731492793242066)
# ('predict', array([6.609869], dtype=float32))
# ('real', 6.699816237611032)
# ('predict', array([6.6252255], dtype=float32))
# ('real', 6.65277722588983)
# ('predict', array([6.642244], dtype=float32))
# ('real', 6.610467064063805)
# ('predict', array([6.6631536], dtype=float32))
# ('real', 6.566930015728635)
# ('predict', array([6.677954], dtype=float32))
# ('real', 6.515801842154499)
# ('predict', array([6.700915], dtype=float32))
# ('real', 6.469866373095678)
# ('predict', array([6.7156887], dtype=float32))
# ('real', 6.415965249038737)
# ('predict', array([6.734286], dtype=float32))
# ('real', 6.360735917995751)
# ('predict', array([6.756391], dtype=float32))
# ('real', 6.304381244059482)
# ('predict', array([6.7721815], dtype=float32))
# ('real', 6.247317341394549)
# ('predict', array([6.796269], dtype=float32))
# ('real', 6.189897723349095)
# ('predict', array([6.8170686], dtype=float32))
# ('real', 6.132487257926093)
# ('predict', array([6.8346586], dtype=float32))
# ('real', 6.082158631433031)
# ('predict', array([6.8539276], dtype=float32))
# ('real', 6.025137375110862)
# ('predict', array([6.8772216], dtype=float32))
# ('real', 5.96907198164867)
# ('predict', array([6.894372], dtype=float32))
# ('real', 5.914125891654004)
# ('predict', array([6.915929], dtype=float32))
# ('real', 5.860941904058343)
# ('predict', array([6.9348326], dtype=float32))
# ('real', 5.81560684000118)
# ('predict', array([6.946524], dtype=float32))
# ('real', 5.768966733406986)
# ('predict', array([6.958375], dtype=float32))
# ('real', 5.721877471004285)
# ('predict', array([6.9664907], dtype=float32))
# ('real', 5.677103648801857)
# ('predict', array([6.978071], dtype=float32))
# ('real', 5.63610641395148)
# ('predict', array([6.987309], dtype=float32))
# ('real', 5.603090510382894)
# ('predict', array([6.9942875], dtype=float32))
# ('real', 5.568109556227123)
# ('predict', array([7.001622], dtype=float32))
# ('real', 5.53553277814269)
# ('predict', array([7.004676], dtype=float32))
# ('real', 5.508131418322076)
# ('predict', array([7.004847], dtype=float32))
# ('real', 5.4774942370201725)
# ('predict', array([7.001483], dtype=float32))
# ('real', 5.447647637661776)
# ('predict', array([6.9946647], dtype=float32))
# ('real', 5.421712122358982)
# ('predict', array([6.987633], dtype=float32))
# ('real', 5.3921353619729135)
# ('predict', array([6.9757423], dtype=float32))
# ('real', 5.362936802088916)
# ('predict', array([6.9633837], dtype=float32))
# ('real', 5.337461513885281)
# ('predict', array([6.9489236], dtype=float32))
# ('real', 5.308401390418803)
# ('predict', array([6.9362073], dtype=float32))
# ('real', 5.2940471339833115)
# ('predict', array([6.9168024], dtype=float32))
# ('real', 5.286896849739742)
# ('predict', array([6.897218], dtype=float32))
# ('real', 5.261594312332592)
# ('predict', array([6.874362], dtype=float32))
# ('real', 5.251104328788628)
# ('predict', array([6.8546295], dtype=float32))
# ('real', 5.220061124905569)
# ('predict', array([6.824762], dtype=float32))
# ('real', 5.179872821234006)
# ('predict', array([6.79569], dtype=float32))
# ('real', 5.155756166824539)
# ('predict', array([6.7632766], dtype=float32))
# ('real', 5.131192967052808)
# ('predict', array([6.7375774], dtype=float32))
# ('real', 5.10709106550815)
# ('predict', array([6.7007146], dtype=float32))
# ('real', 5.086861416199351)
# ('predict', array([6.6678576], dtype=float32))
# ('real', 5.063555572515072)
# ('predict', array([6.631933], dtype=float32))
# ('real', 5.043926848657646)
# ('predict', array([6.6041255], dtype=float32))
# ('real', 5.021266986474142)
# ('predict', array([6.5634794], dtype=float32))
# ('real', 5.002136722440174)
# ('predict', array([6.527835], dtype=float32))
# ('real', 4.977006191987151)
# ('predict', array([6.488299], dtype=float32))
# ('real', 4.958530032635457)
# ('predict', array([6.4583635], dtype=float32))
# ('real', 4.937118261620985)
# ('predict', array([6.4139986], dtype=float32))
# ('real', 4.9161007467606925)
# ('predict', array([6.375604], dtype=float32))
# ('real', 4.892505516208341)
# ('predict', array([6.3435082], dtype=float32))
# ('real', 4.872244422820292)
# ('predict', array([6.2970586], dtype=float32))
# ('real', 4.849489199430666)
# ('predict', array([6.2577195], dtype=float32))
# ('real', 4.830026822934844)
# ('predict', array([6.224983], dtype=float32))
# ('real', 4.807983078258056)
# ('predict', array([6.1777163], dtype=float32))
# ('real', 4.795218806213756)
# ('predict', array([6.1491566], dtype=float32))
# ('real', 4.79019889699096)
# ('predict', array([6.1005936], dtype=float32))
# ('real', 4.774997398479746)
# ('predict', array([6.061727], dtype=float32))
# ('real', 4.769981165827763)
# ('predict', array([6.01878], dtype=float32))
# ('real', 4.755123318756195)
# ('predict', array([5.98831], dtype=float32))
# ('real', 4.738212448717122)
# ('predict', array([5.9425263], dtype=float32))
# ('real', 4.721356777953371)
# ('predict', array([5.905557], dtype=float32))
# ('real', 4.703405561335099)
# ('predict', array([5.865566], dtype=float32))
# ('real', 4.690250692237819)
# ('predict', array([5.837416], dtype=float32))
# ('real', 4.674629729384624)
# ('predict', array([5.7952566], dtype=float32))
# ('real', 4.6584238662642745)
# ('predict', array([5.7623806], dtype=float32))
# ('real', 4.654357136557685)
# ('predict', array([5.7359834], dtype=float32))
# ('real', 4.6419682652100605)
# ('predict', array([5.6976714], dtype=float32))
# ('real', 4.6309102020584705)
# ('predict', array([5.668847], dtype=float32))
# ('real', 4.621622484601324)
# ('predict', array([5.6458592], dtype=float32))
# ('real', 4.614475775679194)
# ('predict', array([5.613562], dtype=float32))
# ('real', 4.602361222568695)
# ('predict', array([5.589483], dtype=float32))
# ('real', 4.591768818516716)
# ('predict', array([5.5701847], dtype=float32))
# ('real', 4.580987380221098)
# ('predict', array([5.5458245], dtype=float32))
# ('real', 4.570842957628167)
# ('predict', array([5.528978], dtype=float32))
# ('real', 4.558798929301835)
# ('predict', array([5.5030994], dtype=float32))
# ('real', 4.548936457083835)
# ('predict', array([5.48262], dtype=float32))
# ('real', 4.5391617976436685)
# ('predict', array([5.4656734], dtype=float32))
# ('real', 4.528768156940302)
# ('predict', array([5.440787], dtype=float32))
# ('real', 4.519638083109083)
# ('predict', array([5.4264913], dtype=float32))
# ('real', 4.512055381551798)
# ('predict', array([5.4011216], dtype=float32))
# ('real', 4.50391292135425)
# ('predict', array([5.3811426], dtype=float32))
# ('real', 4.49770336678187)
# ('predict', array([5.3644414], dtype=float32))
# ('real', 4.49770336678187)
# ('predict', array([5.339624], dtype=float32))
# ('real', 4.496887910364861)
# ('predict', array([5.3195806], dtype=float32))
# ('real', 4.496887910364861)
# ('predict', array([5.3027196], dtype=float32))
# ('real', 4.493760053258142)
# ('predict', array([5.2779355], dtype=float32))
# ('real', 4.488762810743373)
# ('predict', array([5.2577457], dtype=float32))
# ('real', 4.484303645345515)
# ('predict', array([5.240956], dtype=float32))
# ('real', 4.479593795708519)
# ('predict', array([5.2161746], dtype=float32))
# ('real', 2.756619767361426)
# ('predict', array([5.196014], dtype=float32))
# ('real', 2.745689063050846)
# ('predict', array([5.1793013], dtype=float32))
# ('real', 2.75755018185282)
# ('predict', array([5.1547117], dtype=float32))
# ('real', 2.7819134947953117)
# ('predict', array([5.1400433], dtype=float32))
# ('real', 2.8138349417525848)
# ('predict', array([5.1151996], dtype=float32))
# ('real', 2.835370356103186)
# ('predict', array([5.0952973], dtype=float32))
# ('real', 2.852445952056311)
# ('predict', array([5.078897], dtype=float32))
# ('real', 2.8583319481635128)
# ('predict', array([5.0575676], dtype=float32))
# ('real', 2.853755812325641)
# ('predict', array([5.041758], dtype=float32))
# ('real', 2.8472121252764366)
# ('predict', array([5.020913], dtype=float32))
# ('real', 2.8496904219553962)
# ('predict', array([4.999994], dtype=float32))
# ('real', 2.8578552925579364)
# ('predict', array([4.9796667], dtype=float32))
# ('real', 2.8673765131420845)
# ('predict', array([4.964123], dtype=float32))
# ('real', 2.8786936940502095)
# ('predict', array([4.941251], dtype=float32))
# ('real', 2.8893398778489936)
# ('predict', array([4.922483], dtype=float32))
# ('real', 2.902113510259286)
# ('predict', array([4.9072604], dtype=float32))
# ('real', 2.9153868173614166)
# ('predict', array([4.8851037], dtype=float32))
# ('real', 2.9293028470773725)
# ('predict', array([4.8716574], dtype=float32))
# ('real', 2.9460548734510748)
# ('predict', array([4.8498263], dtype=float32))
# ('real', 2.9571492259355123)
# ('predict', array([4.836674], dtype=float32))
# ('real', 2.973880281869925)
# ('predict', array([4.8176255], dtype=float32))
# ('real', 2.991096810483057)
# ('predict', array([4.7998123], dtype=float32))
# ('real', 3.0112189932463083)
# ('predict', array([4.7865367], dtype=float32))
# ('real', 3.029467743038902)
# ('predict', array([4.7663198], dtype=float32))
# ('real', 3.0512264305105847)
# ('predict', array([4.7507405], dtype=float32))
# ('real', 3.0709393958904174)
# ('predict', array([4.7376847], dtype=float32))
# ('real', 3.094388933678505)
# ('predict', array([4.7209754], dtype=float32))
# ('real', 3.1187375147679637)
# ('predict', array([4.7043543], dtype=float32))
# ('real', 3.14399325464288)
# ('predict', array([4.693493], dtype=float32))
# ('real', 3.1669010130084634)
# ('predict', array([4.6760693], dtype=float32))
# ('real', 3.1939468832361397)
# ('predict', array([4.665027], dtype=float32))
# ('real', 3.221810085618658)
# ('predict', array([4.649115], dtype=float32))
# ('real', 3.2468898939062494)
# ('predict', array([4.634988], dtype=float32))
# ('real', 3.2764218311022972)
# ('predict', array([4.624815], dtype=float32))
# ('real', 3.302880210753711)
# ('predict', array([4.609187], dtype=float32))
# ('real', 3.3255872996944364)
# ('predict', array([4.5999775], dtype=float32))
# ('real', 3.358266504580199)
# ('predict', array([4.585132], dtype=float32))
# ('real', 3.38308653643918)
# ('predict', array([4.573308], dtype=float32))
# ('real', 3.3994738692199014)
# ('predict', array([4.5646887], dtype=float32))
# ('real', 3.4139380396661196)
# ('predict', array([4.5512257], dtype=float32))
# ('real', 3.4267416034033986)
# ('predict', array([4.5437784], dtype=float32))
# ('real', 3.4379879328192953)
# ('predict', array([4.530975], dtype=float32))
# ('real', 3.448718195490275)
# ('predict', array([4.5236955], dtype=float32))
# ('real', 3.4585963838767033)
# ('predict', array([4.513178], dtype=float32))
# ('real', 3.4628446936913937)
# ('predict', array([4.505775], dtype=float32))
# ('real', 3.460578690937714)
# ('predict', array([4.4954877], dtype=float32))
# ('real', 3.4502561669674905)
# ('predict', array([4.4880047], dtype=float32))
# ('real', 3.43581993429102)
# ('predict', array([4.4807925], dtype=float32))
# ('real', 3.4203866016768525)
# ('predict', array([4.471778], dtype=float32))
# ('real', 3.400972447787393)
# ('predict', array([4.4648237], dtype=float32))
# ('real', 3.38132234034672)
# ('predict', array([4.4600124], dtype=float32))
# ('real', 3.3558677250166267)
# ('predict', array([4.45202], dtype=float32))
# ('real', 3.3279704489514472)
# ('predict', array([4.445729], dtype=float32))
# ('real', 3.297462117191965)
# ('predict', array([4.4414496], dtype=float32))
# ('real', 3.264193034911084)
# ('predict', array([4.4353576], dtype=float32))
# ('real', 3.2321078568056594)
# ('predict', array([4.432314], dtype=float32))
# ('real', 3.193173876410074)
# ('predict', array([4.4265437], dtype=float32))
# ('real', 3.153246638785579)
# ('predict', array([4.4235344], dtype=float32))
# ('real', 3.122345564420692)
# ('predict', array([4.4190826], dtype=float32))
# ('real', 3.0849516038941003)
# ('predict', array([2.8156164], dtype=float32))
# ('real', 3.0462451057226896)
# ('predict', array([2.5277357], dtype=float32))
# ('real', 3.01189697874234)
# ('predict', array([2.678692], dtype=float32))
# ('real', 2.9643303285454237)
# ('predict', array([2.7273197], dtype=float32))
# ('real', 2.9213490626343757)
# ('predict', array([2.734409], dtype=float32))
# ('real', 2.8768898094099873)
# ('predict', array([2.7438192], dtype=float32))
# ('real', 2.83119581196752)
# ('predict', array([2.7543318], dtype=float32))
# ('real', 2.7776586619817425)
# ('predict', array([2.7651358], dtype=float32))
# ('real', 2.72262849933158)
# ('predict', array([2.7741666], dtype=float32))
# ('real', 2.666216279620767)
# ('predict', array([2.7829068], dtype=float32))
# ('real', 2.616510234191113)
# ('predict', array([2.791016], dtype=float32))
# ('real', 2.559186189842349)
# ('predict', array([2.7972283], dtype=float32))
# ('real', 2.5016110535303144)
# ('predict', array([2.803789], dtype=float32))
# ('real', 2.4433350607342623)
# ('predict', array([2.8103266], dtype=float32))
# ('real', 2.3857631220554074)
# ('predict', array([2.8186576], dtype=float32))
# ('real', 2.3365952249717643)
# ('predict', array([2.8283398], dtype=float32))
# ('real', 2.2880225100099847)
# ('predict', array([2.837536], dtype=float32))
# ('real', 2.2341670460813328)
# ('predict', array([2.8485303], dtype=float32))
# ('real', 2.182605532036083)
# ('predict', array([2.859002], dtype=float32))
# ('real', 2.1398650194063245)
# ('predict', array([2.8715293], dtype=float32))
# ('real', 2.0935454558584174)
# ('predict', array([2.8833025], dtype=float32))
# ('real', 2.0497040308206476)
# ('predict', array([2.897347], dtype=float32))
# ('real', 2.0076327057912913)
# ('predict', array([2.9126992], dtype=float32))
# ('real', 1.9669768575573408)
# ('predict', array([2.9266462], dtype=float32))
# ('real', 1.927310774801811)
# ('predict', array([2.943759], dtype=float32))
# ('real', 1.8933266608761499)
# ('predict', array([2.962389], dtype=float32))
# ('real', 1.8552389851977924)
# ('predict', array([2.9784896], dtype=float32))
# ('real', 1.8227737347464095)
# ('predict', array([2.9968967], dtype=float32))
# ('real', 1.7908648420645428)
# ('predict', array([3.0156786], dtype=float32))
# ('real', 1.7577640418982952)
# ('predict', array([3.031132], dtype=float32))
# ('real', 1.723247097987758)
# ('predict', array([3.0455773], dtype=float32))
# ('real', 1.689732107558777)
# ('predict', array([3.0620272], dtype=float32))
# ('real', 1.661190878341018)
# ('predict', array([3.080837], dtype=float32))
# ('real', 1.637396238380038)
# ('predict', array([3.0967715], dtype=float32))
# ('real', 1.6067925336266637)
# ('predict', array([3.1159775], dtype=float32))
# ('real', 1.5777918716136985)
# ('predict', array([3.1359963], dtype=float32))
# ('real', 1.5501323545743202)
# ('predict', array([3.1524162], dtype=float32))
# ('real', 1.5302838898480735)
# ('predict', array([3.1726658], dtype=float32))
# ('real', 1.5174715094455904)
# ('predict', array([3.1896427], dtype=float32))
# ('real', 1.5081438973642287)
# ('predict', array([3.2105124], dtype=float32))
# ('real', 1.4763230269272696)
# ('predict', array([3.2318642], dtype=float32))
# ('real', 1.4633255959989404)
# ('predict', array([3.2488215], dtype=float32))
# ('real', 1.444103026963347)
# ('predict', array([3.2704175], dtype=float32))
# ('real', 1.428760853247957)
# ('predict', array([3.2923245], dtype=float32))
# ('real', 1.4185342537831525)
# ('predict', array([3.3093898], dtype=float32))
# ('real', 1.414633910045588)
# ('predict', array([3.3320622], dtype=float32))
# ('real', 1.4019877280805328)
# ('predict', array([3.349266], dtype=float32))
# ('real', 1.3957168601542083)
# ('predict', array([3.3690739], dtype=float32))
# ('real', 1.3872398664729342)
# ('predict', array([3.3825846], dtype=float32))
# ('real', 1.380048113667775)
# ('predict', array([3.3961947], dtype=float32))
# ('real', 1.3750050454015428)
# ('predict', array([3.4062712], dtype=float32))
# ('real', 1.3715807052725077)
# ('predict', array([3.4160693], dtype=float32))
# ('real', 1.368100561037625)
# Цель достигнута

# %%
type(testY)
# Out:
# torch.autograd.variable.Variable
